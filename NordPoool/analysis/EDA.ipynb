# %% [markdown]
# https://datos.gob.es/sites/default/files/doc/file/analisis_exploratorio_de_datos_2021.pdf
# https://www.ibm.com/mx-es/think/topics/exploratory-data-analysis
# https://docs.aws.amazon.com/es_es/sagemaker/latest/dg/canvas-analyses.html

# %% [markdown]
# ## **1. DATA DESCRIPTION**

# %% [markdown]
# ## **1.1 Prices**

# %% [markdown]
# 1. **Temporal Scope**
#
#     This dataset contains historical electricity prices from 01/01/2020 to 30/09/2025.
#
#     Data after 1 October 2025 is excluded due to the transition from hourly to 15-minute resolution, ensuring temporal consistency in the analysis.
#
#
# 2. **Geographical Coverage**
#
#     The dataset covers 20 bidding zones, which can be grouped into three larger regions:
#     -  <u>Baltic countries </u>
#
#         Lithuania, Latvia and Estonia
#
#     -  <u>Nordic countries </u>
#
#         Denmark, Finland, Norway and Sweden
#
#     -  <u>Central Western Europe </u>
#
#         Germany, France, the Netherlands, Belgium and Austria
#
#     Denmark, Norway and Sweden are divided into several bidding zones.
#
#     Other bidding zones are only present during a limited period of time and they are excluded from the analysis to ensure consistency in the geographical coverage.
#
#     - Finland-Russia Exchange (01/01/2020 - 03/06/2020)
#     - Great Britain (01/01/2020 - 31/12/2020)
#     - Bulgaria (02/12/2020 - present)
#     - Romania (20/11/2024 - present)
#
# 3. **Temporal Field**
#
#     Delivery day and Delivery period (CET).
#
#
# 4. **Granularity**
#
#     Hourly data.
#
# 5. **Units**
#
#     EUR/MWh
#
# 6. **Structure**
#
#     The dataset is stored in a wide format, where each row represents a delivery period and each bidding zone is represented as a separate column.
#
# 7. **Role in the analysis**
#
#     This dataset represents the main target variable of the study, as it contains the electricity prices to be analyzed and modeled across time and bidding zones.

# %% [markdown]
# ## **1.2 Volumes**

# %% [markdown]
# 1. **Temporal Scope**
#
#     This dataset contains historical electricity market volumes from 01/01/2020 to 30/09/2025.
#
#     Data after 1 October 2025 is excluded due to the transition from hourly to 15-minute resolution, ensuring temporal consistency in the analysis.
#
#
# 2. **Geographical Coverage**
#
#     The dataset covers 20 bidding zones, which can be grouped into three larger regions:
#     -  <u>Baltic countries </u>
#
#         Lithuania, Latvia and Estonia
#
#     -  <u>Nordic countries </u>
#
#         Denmark, Finland, Norway and Sweden
#
#     -  <u>Central Western Europe </u>
#
#         Germany, France, the Netherlands, Belgium and Austria
#
#     Denmark, Norway and Sweden are divided into several bidding zones.
#
#     Other bidding zones are only present during a limited period of time and they are excluded from the analysis to ensure consistency in the geographical coverage.
#
#
# 3. **Temporal Field**
#
#     Delivery day and Delivery period (CET).
#
#
# 4. **Granularity**
#
#     Hourly data.
#
# 5. **Units**
#
#     MWh to ensure consistency with the price dataset, which is expressed in EUR/MWh.
#
# 6. **Structure**
#
#     The dataset is stored in a wide format. For each bidding zone, two consecutive columns are provided, corresponding to Buy and Sell volumes.
#
# 7. **Role in the analysis**
#
#     This dataset represents market activity in each bidding zone, reflecting supply (sell volumes) and demand (buy volumes), and may help explain electricity price dynamics.

# %% [markdown]
# ## **1.3 Flows**

# %% [markdown]
# 1. **Temporal Scope**
#
#     This dataset contains historical directional energy flows from 01/01/2020 to 30/09/2025.
#
#     Data after 1 October 2025 is excluded due to the transition from hourly to 15-minute resolution, ensuring temporal consistency in the analysis.
#
#
# 2. **Geographical Coverage**
#
#     The dataset covers directional interconnections between bidding zones included in the analysis. Each extracted table is centered on a specific delivery area and contains the corresponding import and export flows with neighboring zones.
#
#
# 3. **Temporal Field**
#
#     Delivery day and Delivery period (CET).
#
#
# 4. **Granularity**
#
#     Hourly data.
#
# 5. **Units**
#
#     MWh
#
# 6. **Structure**
#
#     The dataset is stored in a wide format, where each row represents a delivery period and each column represents a directional interconnection between two areas (e.g. NO1 -> NO2, NO2 -> NO1).
#
# 7. **Role in the analysis**
#
#     This dataset captures cross-zonal energy exchanges and provides information about the spatial interaction between bidding zones. It may help explain price differences, market coupling, and network-related events.

# %% [markdown]
# ## **1.4 Capacities**

# %% [markdown]
# 1. **Temporal Scope**
#
#     This dataset contains historical transmission capacities from 01/01/2020 to 30/09/2025.
#
#     Data after 1 October 2025 is excluded due to the transition from hourly to 15-minute resolution, ensuring temporal consistency in the analysis.
#
#
# 2. **Geographical Coverage**
#
#     The dataset covers directional transmission capacities between bidding zones included in the analysis.
#
#     The raw data may include additional technical nodes (e.g. sub-areas or interconnectors), which are excluded to ensure consistency with the bidding zones used in the rest of the study.
#
#
# 3. **Temporal Field**
#
#     Delivery day and Delivery period (CET).
#
#
# 4. **Granularity**
#
#     Hourly data.
#
# 5. **Units**
#
#     MWh
#
# 6. **Structure**
#
#     The dataset is stored in a wide format, where each row represents a delivery period and each column represents a directional capacity between two areas (e.g. NO1 → NO2, NO2 → NO1).
#
# 7. **Role in the analysis**
#
#     This dataset represents the physical limits of the transmission network and provides information about the maximum possible energy exchange between zones. It is essential to identify potential congestion situations and to contextualize observed flows.

# %% [markdown]
# ## **2. DATA LOADING**

# %% [markdown]
# ## **2.1 Prices**

# %% [markdown]
# In this section, the downloaded Excel files corresponding to the Prices dataset are loaded and combined into a single raw dataframe. At this stage, no preprocessing is applied yet.

# %%
import os
import glob
import pandas as pd

# %%
# Base path for the downloaded Prices files
prices_base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\TFG_Data\Prices"

# Read all Excel files from subfolders (e.g. 2020, 2021, ...)
price_files_2020 = glob.glob(os.path.join(prices_base_path, "2020", "*.xlsx"))
price_files_2021 = glob.glob(os.path.join(prices_base_path, "2021", "*.xlsx"))
price_files_2022 = glob.glob(os.path.join(prices_base_path, "2022", "*.xlsx"))
price_files_2023 = glob.glob(os.path.join(prices_base_path, "2023", "*.xlsx"))
price_files_2024 = glob.glob(os.path.join(prices_base_path, "2024", "*.xlsx"))
price_files_2025 = glob.glob(os.path.join(prices_base_path, "2025", "*.xlsx"))

price_files = sorted(price_files_2020 + price_files_2021 + price_files_2022 + price_files_2023 + price_files_2024 + price_files_2025)

print(f"2020 files found: {len(price_files_2020)}")
print(f"2021 files found: {len(price_files_2021)}")
print(f"2022 files found: {len(price_files_2022)}")
print(f"2023 files found: {len(price_files_2023)}")
print(f"2024 files found: {len(price_files_2024)}")
print(f"2025 files found: {len(price_files_2025)}")
print(f"Total files found: {len(price_files)}")
# Out:
# 2020 files found: 366
# 2021 files found: 365
# 2022 files found: 365
# 2023 files found: 365
# 2024 files found: 366
# 2025 files found: 273
# Total files found: 2100

# %% [markdown]
# Track if every price file has been downloaded and loaded correctly.

# %%
import re

path_2021 = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\TFG_Data\Prices\2021"

files = [f for f in os.listdir(path_2021) if f.endswith(".xlsx")]

dates_found = []
for f in files:
    match = re.search(r"\d{4}-\d{2}-\d{2}", f)
    if match:
        dates_found.append(match.group())

dates_found = pd.to_datetime(dates_found)
expected_dates = pd.date_range("2021-01-01", "2021-12-31")

missing_dates = expected_dates.difference(dates_found)

print("Missing dates:")
print(missing_dates)
print("Number of missing dates:", len(missing_dates))
# Out:
# Missing dates:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')
# Number of missing dates: 0

# %% [markdown]
# Loading all files.

# %%
def read_price_file(file):
    df = pd.read_excel(file, header=None)

    # Find the row where the actual table starts
    header_row = df[df.iloc[:, 0].astype(str).str.contains("Delivery period")].index[0]

    # Set that row as the header
    df.columns = df.iloc[header_row]

    # Remove metadata rows above the header
    df = df[(header_row + 1):]

    # Reset index after slicing
    df = df.reset_index(drop=True)

    return df


prices_dfs = []

for file in price_files:
    try:
        # Read file using custom parser
        df = read_price_file(file)

        # Add source file information for traceability
        df["source_file"] = os.path.basename(file)

        prices_dfs.append(df)

    except Exception as e:
        print(f"Error reading {file}: {e}")

# Concatenate all dataframes into a single dataset
prices_raw = pd.concat(prices_dfs, ignore_index=True)

print(f"Combined shape: {prices_raw.shape}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 24
#      21 for file in price_files:
#      22     try:
#      23         # Read file using custom parser
# ---> 24         df = read_price_file(file)
#      26         # Add source file information for traceability
#      27         df["source_file"] = os.path.basename(file)
#
# Cell In[7], line 2, in read_price_file(file)
#       1 def read_price_file(file):
# ----> 2     df = pd.read_excel(file, header=None)
#       4     # Find the row where the actual table starts
#       5     header_row = df[df.iloc[:, 0].astype(str).str.contains("Delivery period")].index[0]
#
# File c:\Users\HUGO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\HUGO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1537, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1534 self._io = stringify_path(path_or_buffer)
#    1536 # Determine xlrd version if installed
# -> 1537 if import_optional_dependency("xlrd", errors="ignore") is None:
#    1538     xlrd_version = None
#    1539 else:
#
# File c:\Users\HUGO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     130 msg = (
#     131     f"Missing optional dependency '{install_name}'. {extra} "
#     132     f"Use pip or conda to install {install_name}."
#     133 )
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#     137     if errors == "raise":
#
# File c:\Users\HUGO\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1322, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:1262, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1525, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1499, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1598, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# First comprovation of the loaded data.

# %%
prices_raw.head()
# Out:
# 4 Delivery period (CET) EE (EUR) LT (EUR) LV (EUR) AT (EUR) BE (EUR) FR (EUR)  \
# 0         00:00 - 01:00    13.55    13.55    13.55    22.26    22.26    22.26
# 1         01:00 - 02:00     7.56     7.56     7.56    20.22    20.22    20.22
# 2         02:00 - 03:00     7.15     7.15     7.15    19.67    19.67    19.67
# 3         03:00 - 04:00     8.02     8.02     8.02    19.25    19.25    19.25
# 4         04:00 - 05:00     7.91     7.91     7.91    19.31    19.31    19.31
#
# 4 GER (EUR) NL (EUR) DK1 (EUR)  ... NO2 (EUR) NO3 (EUR) NO4 (EUR) NO5 (EUR)  \
# 0     22.26    22.26      4.25  ...      4.25      4.25      4.25      4.25
# 1     20.22    20.22      4.27  ...      4.27      4.27      4.27      4.27
# 2     19.67    19.67      4.31  ...      4.31      4.31      4.31      4.31
# 3     19.25    19.25      4.41  ...      4.41      4.41      4.41      4.41
# 4     19.31    19.31      4.53  ...      4.53      4.53      4.53      4.53
#
# 4 SE1 (EUR) SE2 (EUR) SE3 (EUR) SE4 (EUR)  \
# 0      4.25      4.25      4.25      4.25
# 1      4.27      4.27      4.27      4.27
# 2      4.31      4.31      4.31      4.31
# 3      4.41      4.41      4.41      4.41
# 4      4.53      4.53      4.53      4.53
#
# 4                                        source_file PL (EUR)
# 0  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 1  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 2  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 3  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 4  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
#
# [5 rows x 23 columns]

# %%
prices_raw.tail()
# Out:
# 4     Delivery period (CET) EE (EUR) LT (EUR) LV (EUR) AT (EUR) BE (EUR)  \
# 19732         22:00 - 23:00     69.7     69.7     69.7   105.01    35.96
# 19733         23:00 - 00:00    57.98    57.98    57.98    57.98    36.34
# 19734                  Min:    39.11    39.11    39.11    39.11   -40.16
# 19735                  Max:   105.07   105.07   105.07   105.07    92.99
# 19736              Average:    81.49    81.49    81.49    86.96     9.68
#
# 4     FR (EUR) GER (EUR) NL (EUR) DK1 (EUR)  ... NO2 (EUR) NO3 (EUR)  \
# 19732   140.38       5.1       99     32.34  ...    139.18     32.34
# 19733   127.81      6.32     98.2     29.76  ...     138.3     29.76
# 19734    37.33     -0.06        0      5.71  ...    112.88     24.01
# 19735   193.15     62.23   142.53    105.07  ...    147.24     55.36
# 19736   120.02     12.13    78.63     42.61  ...    135.85      37.9
#
# 4     NO4 (EUR) NO5 (EUR) SE1 (EUR) SE2 (EUR) SE3 (EUR) SE4 (EUR)  \
# 19732     32.34    139.18     32.34     32.34     32.34     32.34
# 19733     29.76     138.3     29.76     29.76     29.76     29.76
# 19734     24.01    112.88     24.01     24.01     24.01     24.01
# 19735     55.36    147.24     55.36     55.36    105.07    105.07
# 19736      37.9    135.85      37.9      37.9     43.62     43.62
#
# 4                                            source_file PL (EUR)
# 19732  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 19733  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 19734  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 19735  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
# 19736  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...      NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **2.2 Volumes**

# %% [markdown]
# The volumes dataset was provided as a collection of daily Excel files downloaded from Nord Pool. Each file contains hourly observations for the selected market areas, together with separate trading volume values for the buy and sell sides of the market. Since these two values are displayed as adjacent columns for each area without fully explicit labelling in the file structure, an additional loading step was required to reconstruct the column names correctly and distinguish between buy and sell series for each bidding zone.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

def load_single_volume_file(file_path):
    """
    Carga un archivo diario de volumes de Nord Pool y devuelve
    un DataFrame limpio con columnas tipo EE_Buy, EE_Sell, etc.
    """
    file_path = Path(file_path)

    # Leer el excel sin cabecera fija
    raw = pd.read_excel(file_path, header=None)

    # -----------------------------
    # 1. Extraer metadatos básicos
    # -----------------------------
    # Según la estructura mostrada:
    # fila 0 -> Areas
    # fila 1 -> Market
    # fila 2 -> Delivery day
    areas_raw = raw.iloc[0, 1]
    delivery_day_raw = raw.iloc[2, 1]

    delivery_day = pd.to_datetime(delivery_day_raw)

    # -----------------------------
    # 2. Extraer encabezados reales
    # -----------------------------
    # fila 3 contiene algo como:
    # Delivery period (CET), EE, EE, LT, LT, ...
    header_row = raw.iloc[3].tolist()

    # Primera columna = Delivery period
    columns = ["Delivery period (CET)"]

    # El resto viene en pares Buy/Sell
    area_names = header_row[1:]

    for i, area in enumerate(area_names):
        if pd.isna(area):
            columns.append(f"Unknown_{i}")
        else:
            side = "Buy" if i % 2 == 0 else "Sell"
            columns.append(f"{str(area).strip()}_{side}")

    # -----------------------------
    # 3. Extraer cuerpo de datos
    # -----------------------------
    data = raw.iloc[4:].copy()
    data.columns = columns

    # Eliminar filas completamente vacías
    data = data.dropna(how="all")

    # -----------------------------
    # 4. Eliminar filas resumen
    # -----------------------------
    summary_rows = ["Min:", "Max:", "Average:", "Total (MWh):"]
    data = data[~data["Delivery period (CET)"].astype(str).isin(summary_rows)]

    # -----------------------------
    # 5. Limpiar tipos
    # -----------------------------
    # Convertir columnas numéricas
    numeric_cols = [col for col in data.columns if col != "Delivery period (CET)"]
    data[numeric_cols] = data[numeric_cols].apply(pd.to_numeric, errors="coerce")

    # -----------------------------
    # 6. Añadir variables temporales
    # -----------------------------
    data["Delivery day"] = delivery_day

    # Sacar hora de inicio del tramo horario
    # Ej: "00:00 - 01:00" -> 0
    data["hour"] = (
        data["Delivery period (CET)"]
        .astype(str)
        .str.split(" - ")
        .str[0]
        .str.slice(0, 2)
        .astype(int)
    )

    data["timestamp"] = data["Delivery day"] + pd.to_timedelta(data["hour"], unit="h")

    # Reset index
    data = data.reset_index(drop=True)

    return data

# %%
file_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\2020\auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-01_MW.xlsx"

volumes_test = load_single_volume_file(file_path)

print(volumes_test.head())
print(volumes_test.columns.tolist())
print(volumes_test.info())
# Out:
#   Delivery period (CET)  EE_Buy  EE_Sell  LT_Buy  LT_Sell  LV_Buy  LV_Sell  \
# 0         00:00 - 01:00   688.8    283.8  1005.3   1703.4   689.7    220.3
# 1         01:00 - 02:00   680.7    284.8   965.3   1677.5   663.4    215.4
# 2         02:00 - 03:00   669.8    281.2   936.2   1365.5   637.2    217.9
# 3         03:00 - 04:00   666.4    266.2   931.5   1309.5   619.1    218.0
# 4         04:00 - 05:00   663.0    252.6   927.6   1001.5   618.4    316.0
#
#    AT_Buy  AT_Sell  BE_Buy  ...  SE1_Sell  SE2_Buy  SE2_Sell  SE3_Buy  \
# 0   452.0     22.6   119.5  ...    1151.6   1368.0    3762.5   7477.8
# 1   536.2    143.8   122.8  ...    1059.1   1329.7    3386.6   7278.4
# 2   576.6     84.2   129.8  ...    1018.0   1304.3    3334.4   7100.4
# 3   626.6     35.6   137.9  ...     994.9   1286.9    3328.0   6960.6
# 4   596.6      0.0   150.6  ...     992.5   1283.8    3437.6   6925.3
#
#    SE3_Sell  SE4_Buy  SE4_Sell  Delivery day  hour           timestamp
# 0   10059.4   2151.5     684.6    2020-01-01     0 2020-01-01 00:00:00
# 1   10132.4   2066.3     727.0    2020-01-01     1 2020-01-01 01:00:00
# 2   10192.6   1986.5     777.5    2020-01-01     2 2020-01-01 02:00:00
# 3   10259.1   1899.2     823.9    2020-01-01     3 2020-01-01 03:00:00
# 4   10371.9   1850.8     863.1    2020-01-01     4 2020-01-01 04:00:00
#
# [5 rows x 44 columns]
# ['Delivery period (CET)', 'EE_Buy', 'EE_Sell', 'LT_Buy', 'LT_Sell', 'LV_Buy', 'LV_Sell', 'AT_Buy', 'AT_Sell', 'BE_Buy', 'BE_Sell', 'FR_Buy', 'FR_Sell', 'GER_Buy', 'GER_Sell', 'NL_Buy', 'NL_Sell', 'DK1_Buy', 'DK1_Sell', 'DK2_Buy', 'DK2_Sell', 'FI_Buy', 'FI_Sell', 'NO1_Buy', 'NO1_Sell', 'NO2_Buy', 'NO2_Sell', 'NO3_Buy', 'NO3_Sell', 'NO4_Buy', 'NO4_Sell', 'NO5_Buy', 'NO5_Sell', 'SE1_Buy', 'SE1_Sell', 'SE2_Buy', 'SE2_Sell', 'SE3_Buy', 'SE3_Sell', 'SE4_Buy', 'SE4_Sell', 'Delivery day', 'hour', 'timestamp']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Delivery period (CET)  24 non-null     object
#  1   EE_Buy                 24 non-null     float64
#  2   EE_Sell                24 non-null     float64
#  3   LT_Buy                 24 non-null     float64
#  4   LT_Sell                24 non-null     float64
#  5   LV_Buy                 24 non-null     float64
#  6   LV_Sell                24 non-null     float64
#  7   AT_Buy                 24 non-null     float64
#  8   AT_Sell                24 non-null     float64
#  9   BE_Buy                 24 non-null     float64
#  10  BE_Sell                24 non-null     float64
#  11  FR_Buy                 24 non-null     float64
#  12  FR_Sell                24 non-null     float64
#  13  GER_Buy                24 non-null     float64
#  14  GER_Sell               24 non-null     float64
#  15  NL_Buy                 24 non-null     float64
#  16  NL_Sell                24 non-null     float64
#  17  DK1_Buy                24 non-null     float64
#  18  DK1_Sell               24 non-null     float64
#  19  DK2_Buy                24 non-null     float64
#  20  DK2_Sell               24 non-null     float64
#  21  FI_Buy                 24 non-null     float64
#  22  FI_Sell                24 non-null     float64
#  23  NO1_Buy                24 non-null     float64
#  24  NO1_Sell               24 non-null     float64
#  25  NO2_Buy                24 non-null     float64
#  26  NO2_Sell               24 non-null     float64
#  27  NO3_Buy                24 non-null     float64
#  28  NO3_Sell               24 non-null     float64
#  29  NO4_Buy                24 non-null     float64
#  30  NO4_Sell               24 non-null     float64
#  31  NO5_Buy                24 non-null     float64
#  32  NO5_Sell               24 non-null     float64
#  33  SE1_Buy                24 non-null     float64
#  34  SE1_Sell               24 non-null     float64
#  35  SE2_Buy                24 non-null     float64
#  36  SE2_Sell               24 non-null     float64
#  37  SE3_Buy                24 non-null     float64
#  38  SE3_Sell               24 non-null     float64
#  39  SE4_Buy                24 non-null     float64
#  40  SE4_Sell               24 non-null     float64
#  41  Delivery day           24 non-null     datetime64[ns]
#  42  hour                   24 non-null     int32
#  43  timestamp              24 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(40), int32(1), object(1)
# memory usage: 8.3+ KB
# None

# %%
from pathlib import Path
import pandas as pd

def load_all_volume_files(folder_path):
    folder = Path(folder_path)
    all_files = sorted(folder.glob("*.xlsx"))

    dfs = []

    for file in all_files:
        try:
            df = load_single_volume_file(file)
            df["source_file"] = file.name
            dfs.append(df)
            print(f"Loaded: {file.name}")
        except Exception as e:
            print(f"Error loading {file.name}: {e}")

    if not dfs:
        raise ValueError("No files could be loaded.")

    volumes = pd.concat(dfs, ignore_index=True)
    return volumes

# %%
folders = [
    r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\2020",
    r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\2021"
]

dfs = []

for folder_path in folders:
    df = load_all_volume_files(folder_path)
    dfs.append(df)

volumes = pd.concat(dfs, ignore_index=True)

print(volumes.shape)
print(volumes.head())
print(volumes.info())
# Out:
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-01-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-02-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-03-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-04-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-05-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-06-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-07-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-08-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-09-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-10-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-11-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2020-12-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-01-21_MW.xlsx
# ...
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-10-31_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-11-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-01_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-02_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-03_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-04_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-05_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-06_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-07_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-08_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-09_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-10_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-11_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-12_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-13_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-14_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-15_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-16_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-17_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-18_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-19_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-20_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-21_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-22_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-23_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-24_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-25_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-26_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-27_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-28_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-29_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-30_MW.xlsx
# Loaded: auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,DK2,FI,NO1,NO2,NO3,NO4,NO5,SE1,SE2,SE3,SE4_DayAhead_2021-12-31_MW.xlsx
# (17544, 45)
#   Delivery period (CET)  EE_Buy  EE_Sell  LT_Buy  LT_Sell  LV_Buy  LV_Sell  \
# 0         00:00 - 01:00   688.8    283.8  1005.3   1703.4   689.7    220.3
# 1         01:00 - 02:00   680.7    284.8   965.3   1677.5   663.4    215.4
# 2         02:00 - 03:00   669.8    281.2   936.2   1365.5   637.2    217.9
# 3         03:00 - 04:00   666.4    266.2   931.5   1309.5   619.1    218.0
# 4         04:00 - 05:00   663.0    252.6   927.6   1001.5   618.4    316.0
#
#    AT_Buy  AT_Sell  BE_Buy  ...  SE2_Buy  SE2_Sell  SE3_Buy  SE3_Sell  \
# 0   452.0     22.6   119.5  ...   1368.0    3762.5   7477.8   10059.4
# 1   536.2    143.8   122.8  ...   1329.7    3386.6   7278.4   10132.4
# 2   576.6     84.2   129.8  ...   1304.3    3334.4   7100.4   10192.6
# 3   626.6     35.6   137.9  ...   1286.9    3328.0   6960.6   10259.1
# 4   596.6      0.0   150.6  ...   1283.8    3437.6   6925.3   10371.9
#
#    SE4_Buy  SE4_Sell  Delivery day  hour           timestamp  \
# 0   2151.5     684.6    2020-01-01     0 2020-01-01 00:00:00
# 1   2066.3     727.0    2020-01-01     1 2020-01-01 01:00:00
# 2   1986.5     777.5    2020-01-01     2 2020-01-01 02:00:00
# 3   1899.2     823.9    2020-01-01     3 2020-01-01 03:00:00
# 4   1850.8     863.1    2020-01-01     4 2020-01-01 04:00:00
#
#                                          source_file
# 0  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 1  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 2  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 3  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 4  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
#
# [5 rows x 45 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Delivery period (CET)  17544 non-null  object
#  1   EE_Buy                 17544 non-null  float64
#  2   EE_Sell                17544 non-null  float64
#  3   LT_Buy                 17544 non-null  float64
#  4   LT_Sell                17544 non-null  float64
#  5   LV_Buy                 17544 non-null  float64
#  6   LV_Sell                17544 non-null  float64
#  7   AT_Buy                 17544 non-null  float64
#  8   AT_Sell                17544 non-null  float64
#  9   BE_Buy                 17544 non-null  float64
#  10  BE_Sell                17544 non-null  float64
#  11  FR_Buy                 17544 non-null  float64
#  12  FR_Sell                17544 non-null  float64
#  13  GER_Buy                17544 non-null  float64
#  14  GER_Sell               17544 non-null  float64
#  15  NL_Buy                 17544 non-null  float64
#  16  NL_Sell                17544 non-null  float64
#  17  DK1_Buy                17544 non-null  float64
#  18  DK1_Sell               17544 non-null  float64
#  19  DK2_Buy                17544 non-null  float64
#  20  DK2_Sell               17544 non-null  float64
#  21  FI_Buy                 17544 non-null  float64
#  22  FI_Sell                17544 non-null  float64
#  23  NO1_Buy                17544 non-null  float64
#  24  NO1_Sell               17544 non-null  float64
#  25  NO2_Buy                17544 non-null  float64
#  26  NO2_Sell               17544 non-null  float64
#  27  NO3_Buy                17544 non-null  float64
#  28  NO3_Sell               17544 non-null  float64
#  29  NO4_Buy                17544 non-null  float64
#  30  NO4_Sell               17544 non-null  float64
#  31  NO5_Buy                17544 non-null  float64
#  32  NO5_Sell               17544 non-null  float64
#  33  SE1_Buy                17544 non-null  float64
#  34  SE1_Sell               17544 non-null  float64
#  35  SE2_Buy                17544 non-null  float64
#  36  SE2_Sell               17544 non-null  float64
#  37  SE3_Buy                17544 non-null  float64
#  38  SE3_Sell               17544 non-null  float64
#  39  SE4_Buy                17544 non-null  float64
#  40  SE4_Sell               17544 non-null  float64
#  41  Delivery day           17544 non-null  datetime64[ns]
#  42  hour                   17544 non-null  int32
#  43  timestamp              17544 non-null  datetime64[ns]
#  44  source_file            17544 non-null  object
# dtypes: datetime64[ns](2), float64(40), int32(1), object(2)
# memory usage: 6.0+ MB
# None

# %%
print(volumes["Delivery day"].min())
print(volumes["Delivery day"].max())
print(volumes["Delivery day"].nunique())
# Out:
# 2020-01-01 00:00:00
# 2021-12-31 00:00:00
# 731

# %% [markdown]
# The volumes dataset was constructed by combining daily Excel files downloaded from the Nord Pool platform for the period between January 1st, 2020 and December 31st, 2021. Each file contains hourly observations for multiple market areas, including separate values for buy and sell volumes.
#
# A custom loading procedure was implemented to correctly reconstruct the dataset structure, as buy and sell values are stored in adjacent columns without explicit labels in the original files. This process resulted in a final dataset containing 17,544 hourly observations and 45 variables.
#
# The dataset covers a total of 731 days, with no missing dates, ensuring full temporal continuity and consistency with the electricity prices dataset analysed previously.

# %% [markdown]
# ## **2.3 Flows**

# %% [markdown]
# ## **3. DATA PREPROCESSING**

# %% [markdown]
# ## **3.1 Prices**

# %% [markdown]
# In this section, the raw Prices dataset is cleaned and transformed in order to make it suitable for exploratory analysis. The preprocessing includes removing summary rows, cleaning column names, extracting the delivery date from the source file, and creating a proper timestamp.

# %%
prices = prices_raw.copy()

# %% [markdown]
# Next step is deleting unnecessary columns and rows.

# %%
# Remove summary rows that do not correspond to actual delivery periods
prices = prices[
    ~prices["Delivery period (CET)"].astype(str).str.contains("Min|Max|Average", na=False)
]

# Reset index after filtering
prices = prices.reset_index(drop=True)

# %% [markdown]
# And the following step is clean column names.

# %%
# Clean column names by removing the currency suffix
prices.columns = [
    col.replace(" (EUR)", "") if isinstance(col, str) else col
    for col in prices.columns
]

# %% [markdown]
# Extract delivery date from the source file name and create a proper timestamp.

# %%
# Extract delivery day from the source file name
prices["Delivery day"] = prices["source_file"].str.extract(r"(\d{4}-\d{2}-\d{2})")

# Convert delivery day to datetime
prices["Delivery day"] = pd.to_datetime(prices["Delivery day"])

# Extract the starting hour from the delivery period
prices["hour"] = prices["Delivery period (CET)"].str[:2].astype(int)

# Create a full timestamp combining delivery day and hour
prices["timestamp"] = prices["Delivery day"] + pd.to_timedelta(prices["hour"], unit="h")

# Sort dataset chronologically
prices = prices.sort_values("timestamp").reset_index(drop=True)

# %%
prices.head()
# Out:
#   Delivery period (CET)     EE     LT     LV     AT     BE     FR    GER  \
# 0         00:00 - 01:00  28.78  28.78  28.78  41.88  41.88  41.88  41.88
# 1         01:00 - 02:00  28.45  28.45  28.45   38.6   38.6   38.6   38.6
# 2         02:00 - 03:00   27.9   27.9   27.9  36.55  36.55  36.55  36.55
# 3         03:00 - 04:00  27.52  27.52  27.52  32.32  32.32  32.32  32.32
# 4         04:00 - 05:00  27.54  27.54  27.54  30.85  30.85  30.85  30.85
#
#       NL    DK1  ...    NO5    SE1    SE2    SE3    SE4  \
# 0  41.88  33.42  ...  31.82  28.78  28.78  28.78  28.78
# 1   38.6  31.77  ...  31.77  28.45  28.45  28.45  28.45
# 2  36.55  31.57  ...  31.57   27.9   27.9   27.9   27.9
# 3  32.32  31.28  ...  31.28  27.52  27.52  27.52  27.52
# 4  30.85  30.85  ...  30.72  27.54  27.54  27.54  27.54
#
#                                          source_file   PL Delivery day hour  \
# 0  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...  NaN   2020-01-01    0
# 1  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...  NaN   2020-01-01    1
# 2  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...  NaN   2020-01-01    2
# 3  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...  NaN   2020-01-01    3
# 4  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...  NaN   2020-01-01    4
#
#             timestamp
# 0 2020-01-01 00:00:00
# 1 2020-01-01 01:00:00
# 2 2020-01-01 02:00:00
# 3 2020-01-01 03:00:00
# 4 2020-01-01 04:00:00
#
# [5 rows x 26 columns]

# %%
print("Duplicate timestamps in prices:", prices.duplicated(subset=["timestamp"]).sum())

duplicates_ts_prices = prices[prices.duplicated(subset=["timestamp"], keep=False)]
print(duplicates_ts_prices[["Delivery day", "Delivery period (CET)", "hour", "timestamp"]].sort_values("timestamp"))
# Out:
# Duplicate timestamps in prices: 2
#       Delivery day Delivery period (CET)  hour           timestamp
# 7153    2020-10-25         02:00 - 02:00     2 2020-10-25 02:00:00
# 7154    2020-10-25         02:00 - 03:00     2 2020-10-25 02:00:00
# 16057   2021-10-31         02:00 - 03:00     2 2021-10-31 02:00:00
# 16058   2021-10-31         02:00 - 02:00     2 2021-10-31 02:00:00

# %%
prices.columns.tolist()
# Out:
# ['Delivery period (CET)',
#  'EE',
#  'LT',
#  'LV',
#  'AT',
#  'BE',
#  'FR',
#  'GER',
#  'NL',
#  'DK1',
#  'DK2',
#  'FI',
#  'NO1',
#  'NO2',
#  'NO3',
#  'NO4',
#  'NO5',
#  'SE1',
#  'SE2',
#  'SE3',
#  'SE4',
#  'source_file',
#  'PL',
#  'Delivery day',
#  'hour',
#  'timestamp']

# %% [markdown]
# Even we decided to exclude some zones to ensure consistency in the geographical coverage, there are few data from PL we need to remove to avoid inconsistencies in the analysis.

# %%
# Drop unwanted zones
prices = prices.drop(columns=["PL"], errors="ignore")

# %%
prices.head()
# Out:
#   Delivery period (CET)     EE     LT     LV     AT     BE     FR    GER  \
# 0         00:00 - 01:00  28.78  28.78  28.78  41.88  41.88  41.88  41.88
# 1         01:00 - 02:00  28.45  28.45  28.45   38.6   38.6   38.6   38.6
# 2         02:00 - 03:00   27.9   27.9   27.9  36.55  36.55  36.55  36.55
# 3         03:00 - 04:00  27.52  27.52  27.52  32.32  32.32  32.32  32.32
# 4         04:00 - 05:00  27.54  27.54  27.54  30.85  30.85  30.85  30.85
#
#       NL    DK1  ...    NO4    NO5    SE1    SE2    SE3    SE4  \
# 0  41.88  33.42  ...  28.78  31.82  28.78  28.78  28.78  28.78
# 1   38.6  31.77  ...  28.45  31.77  28.45  28.45  28.45  28.45
# 2  36.55  31.57  ...   27.9  31.57   27.9   27.9   27.9   27.9
# 3  32.32  31.28  ...  27.52  31.28  27.52  27.52  27.52  27.52
# 4  30.85  30.85  ...  27.54  30.72  27.54  27.54  27.54  27.54
#
#                                          source_file Delivery day hour  \
# 0  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...   2020-01-01    0
# 1  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...   2020-01-01    1
# 2  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...   2020-01-01    2
# 3  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...   2020-01-01    3
# 4  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...   2020-01-01    4
#
#             timestamp
# 0 2020-01-01 00:00:00
# 1 2020-01-01 01:00:00
# 2 2020-01-01 02:00:00
# 3 2020-01-01 03:00:00
# 4 2020-01-01 04:00:00
#
# [5 rows x 25 columns]

# %% [markdown]
# Last verification of the preprocessed data.

# %%
prices.shape
prices[["timestamp", "Delivery day", "Delivery period (CET)"]].head()
prices.isna().sum().sort_values(ascending=False).head(10)
# Out:
# Delivery period (CET)    0
# NO2                      0
# hour                     0
# Delivery day             0
# source_file              0
# SE4                      0
# SE3                      0
# SE2                      0
# SE1                      0
# NO5                      0
# dtype: int64

# %% [markdown]
# ## **3.2 Volumes**

# %% [markdown]
# <u> 3.2.1 Basic validation of the loaded dataset </u>

# %%
print(volumes.shape)
print(volumes.info())
print(volumes.head())
# Out:
# (17544, 45)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Delivery period (CET)  17544 non-null  object
#  1   EE_Buy                 17544 non-null  float64
#  2   EE_Sell                17544 non-null  float64
#  3   LT_Buy                 17544 non-null  float64
#  4   LT_Sell                17544 non-null  float64
#  5   LV_Buy                 17544 non-null  float64
#  6   LV_Sell                17544 non-null  float64
#  7   AT_Buy                 17544 non-null  float64
#  8   AT_Sell                17544 non-null  float64
#  9   BE_Buy                 17544 non-null  float64
#  10  BE_Sell                17544 non-null  float64
#  11  FR_Buy                 17544 non-null  float64
#  12  FR_Sell                17544 non-null  float64
#  13  GER_Buy                17544 non-null  float64
#  14  GER_Sell               17544 non-null  float64
#  15  NL_Buy                 17544 non-null  float64
#  16  NL_Sell                17544 non-null  float64
#  17  DK1_Buy                17544 non-null  float64
#  18  DK1_Sell               17544 non-null  float64
#  19  DK2_Buy                17544 non-null  float64
#  20  DK2_Sell               17544 non-null  float64
#  21  FI_Buy                 17544 non-null  float64
#  22  FI_Sell                17544 non-null  float64
#  23  NO1_Buy                17544 non-null  float64
#  24  NO1_Sell               17544 non-null  float64
#  25  NO2_Buy                17544 non-null  float64
#  26  NO2_Sell               17544 non-null  float64
#  27  NO3_Buy                17544 non-null  float64
#  28  NO3_Sell               17544 non-null  float64
#  29  NO4_Buy                17544 non-null  float64
#  30  NO4_Sell               17544 non-null  float64
#  31  NO5_Buy                17544 non-null  float64
#  32  NO5_Sell               17544 non-null  float64
#  33  SE1_Buy                17544 non-null  float64
#  34  SE1_Sell               17544 non-null  float64
#  35  SE2_Buy                17544 non-null  float64
#  36  SE2_Sell               17544 non-null  float64
#  37  SE3_Buy                17544 non-null  float64
#  38  SE3_Sell               17544 non-null  float64
#  39  SE4_Buy                17544 non-null  float64
#  40  SE4_Sell               17544 non-null  float64
#  41  Delivery day           17544 non-null  datetime64[ns]
#  42  hour                   17544 non-null  int32
#  43  timestamp              17544 non-null  datetime64[ns]
#  44  source_file            17544 non-null  object
# dtypes: datetime64[ns](2), float64(40), int32(1), object(2)
# memory usage: 6.0+ MB
# None
#   Delivery period (CET)  EE_Buy  EE_Sell  LT_Buy  LT_Sell  LV_Buy  LV_Sell  \
# 0         00:00 - 01:00   688.8    283.8  1005.3   1703.4   689.7    220.3
# 1         01:00 - 02:00   680.7    284.8   965.3   1677.5   663.4    215.4
# 2         02:00 - 03:00   669.8    281.2   936.2   1365.5   637.2    217.9
# 3         03:00 - 04:00   666.4    266.2   931.5   1309.5   619.1    218.0
# 4         04:00 - 05:00   663.0    252.6   927.6   1001.5   618.4    316.0
#
#    AT_Buy  AT_Sell  BE_Buy  ...  SE2_Buy  SE2_Sell  SE3_Buy  SE3_Sell  \
# 0   452.0     22.6   119.5  ...   1368.0    3762.5   7477.8   10059.4
# 1   536.2    143.8   122.8  ...   1329.7    3386.6   7278.4   10132.4
# 2   576.6     84.2   129.8  ...   1304.3    3334.4   7100.4   10192.6
# 3   626.6     35.6   137.9  ...   1286.9    3328.0   6960.6   10259.1
# 4   596.6      0.0   150.6  ...   1283.8    3437.6   6925.3   10371.9
#
#    SE4_Buy  SE4_Sell  Delivery day  hour           timestamp  \
# 0   2151.5     684.6    2020-01-01     0 2020-01-01 00:00:00
# 1   2066.3     727.0    2020-01-01     1 2020-01-01 01:00:00
# 2   1986.5     777.5    2020-01-01     2 2020-01-01 02:00:00
# 3   1899.2     823.9    2020-01-01     3 2020-01-01 03:00:00
# 4   1850.8     863.1    2020-01-01     4 2020-01-01 04:00:00
#
#                                          source_file
# 0  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 1  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 2  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 3  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 4  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
#
# [5 rows x 45 columns]

# %% [markdown]
# <u> 3.2.2 Missing values </u>

# %%
print(volumes.isnull().sum())
print("Total missing values:", volumes.isnull().sum().sum())
# Out:
# Delivery period (CET)    0
# EE_Buy                   0
# EE_Sell                  0
# LT_Buy                   0
# LT_Sell                  0
# LV_Buy                   0
# LV_Sell                  0
# AT_Buy                   0
# AT_Sell                  0
# BE_Buy                   0
# BE_Sell                  0
# FR_Buy                   0
# FR_Sell                  0
# GER_Buy                  0
# GER_Sell                 0
# NL_Buy                   0
# NL_Sell                  0
# DK1_Buy                  0
# DK1_Sell                 0
# DK2_Buy                  0
# DK2_Sell                 0
# FI_Buy                   0
# FI_Sell                  0
# NO1_Buy                  0
# NO1_Sell                 0
# NO2_Buy                  0
# NO2_Sell                 0
# NO3_Buy                  0
# NO3_Sell                 0
# NO4_Buy                  0
# NO4_Sell                 0
# NO5_Buy                  0
# NO5_Sell                 0
# SE1_Buy                  0
# SE1_Sell                 0
# SE2_Buy                  0
# SE2_Sell                 0
# SE3_Buy                  0
# SE3_Sell                 0
# SE4_Buy                  0
# SE4_Sell                 0
# Delivery day             0
# hour                     0
# timestamp                0
# source_file              0
# dtype: int64
# Total missing values: 0

# %% [markdown]
# <u> 3.2.3 Duplicates </u>

# %%
duplicates = volumes.duplicated().sum()
print("Total duplicate rows:", duplicates)
# Out:
# Total duplicate rows: 0

# %%
timestamp_duplicates = volumes.duplicated(subset=["timestamp"]).sum()
print("Duplicate timestamps:", timestamp_duplicates)
# Out:
# Duplicate timestamps: 2

# %%
duplicates_ts = volumes[volumes.duplicated(subset=["timestamp"], keep=False)]
print(duplicates_ts.sort_values("timestamp"))
# Out:
#       Delivery period (CET)  EE_Buy  EE_Sell  LT_Buy  LT_Sell  LV_Buy  \
# 7153          02:00 - 02:00   591.2    193.3   966.9    518.1   594.3
# 7154          02:00 - 03:00   591.3    191.6   966.4    503.1   594.3
# 16057         02:00 - 02:00   654.1    518.8  1099.7    659.1   597.6
# 16058         02:00 - 03:00   653.4    522.7  1154.4    662.9   594.3
#
#        LV_Sell  AT_Buy  AT_Sell  BE_Buy  ...  SE2_Buy  SE2_Sell  SE3_Buy  \
# 7153     280.3   181.0     24.3    65.7  ...   1520.6    3988.8   6275.1
# 7154     280.3   181.0     24.3    58.7  ...   1511.9    3931.4   6218.0
# 16057    151.1     0.0     18.5    76.3  ...   1160.1    3163.5   6026.1
# 16058    205.1     0.0     18.5    85.7  ...   1149.0    3180.6   6004.4
#
#        SE3_Sell  SE4_Buy  SE4_Sell  Delivery day  hour           timestamp  \
# 7153     6971.2   1455.4     399.9    2020-10-25     2 2020-10-25 02:00:00
# 7154     6961.5   1448.7     393.9    2020-10-25     2 2020-10-25 02:00:00
# 16057    6694.7   1617.0     424.9    2021-10-31     2 2021-10-31 02:00:00
# 16058    6768.4   1611.1     442.6    2021-10-31     2 2021-10-31 02:00:00
#
#                                              source_file
# 7153   auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 7154   auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 16057  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
# 16058  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...
#
# [4 rows x 45 columns]

# %% [markdown]
# During the preprocessing stage, a small number of duplicated timestamps were identified. A detailed inspection revealed that these duplicates correspond to the daylight saving time (DST) transitions, specifically on October 25th, 2020 and October 31st, 2021.
#
# On these dates, the clock is adjusted backwards, resulting in one hour being recorded twice. Consequently, two distinct observations share the same timestamp but represent different physical time intervals.
#
# These observations were not removed, as they reflect real market conditions and are consistent with the structure of electricity market data.

# %% [markdown]
# <u> 3.2.4 Data types </u>

# %%
print(volumes.dtypes)
# Out:
# Delivery period (CET)            object
# EE_Buy                          float64
# EE_Sell                         float64
# LT_Buy                          float64
# LT_Sell                         float64
# LV_Buy                          float64
# LV_Sell                         float64
# AT_Buy                          float64
# AT_Sell                         float64
# BE_Buy                          float64
# BE_Sell                         float64
# FR_Buy                          float64
# FR_Sell                         float64
# GER_Buy                         float64
# GER_Sell                        float64
# NL_Buy                          float64
# NL_Sell                         float64
# DK1_Buy                         float64
# DK1_Sell                        float64
# DK2_Buy                         float64
# DK2_Sell                        float64
# FI_Buy                          float64
# FI_Sell                         float64
# NO1_Buy                         float64
# NO1_Sell                        float64
# NO2_Buy                         float64
# NO2_Sell                        float64
# NO3_Buy                         float64
# NO3_Sell                        float64
# NO4_Buy                         float64
# NO4_Sell                        float64
# NO5_Buy                         float64
# NO5_Sell                        float64
# SE1_Buy                         float64
# SE1_Sell                        float64
# SE2_Buy                         float64
# SE2_Sell                        float64
# SE3_Buy                         float64
# SE3_Sell                        float64
# SE4_Buy                         float64
# SE4_Sell                        float64
# Delivery day             datetime64[ns]
# hour                              int32
# timestamp                datetime64[ns]
# source_file                      object
# dtype: object

# %%
volumes["Delivery day"] = pd.to_datetime(volumes["Delivery day"])

# %% [markdown]
# <u> 3.2.5 Buy/Sell column identification </u>

# %%
buy_cols = [col for col in volumes.columns if col.endswith("_Buy")]
sell_cols = [col for col in volumes.columns if col.endswith("_Sell")]

print("Number of Buy columns:", len(buy_cols))
print("Number of Sell columns:", len(sell_cols))
# Out:
# Number of Buy columns: 20
# Number of Sell columns: 20

# %% [markdown]
# <u> 3.2.6 Temporal consistency </u>

# %%
print(volumes["Delivery day"].min())
print(volumes["Delivery day"].max())
print(volumes["Delivery day"].nunique())
print(len(volumes))
# Out:
# 2020-01-01 00:00:00
# 2021-12-31 00:00:00
# 731
# 17544

# %% [markdown]
# <u>Conclusion</u>

# %% [markdown]
# The preprocessing stage confirmed that the dataset is complete and consistent, with no missing values or duplicate observations, except for a small number of duplicated timestamps due to daylight saving time adjustments. All variables were correctly formatted, and the dataset structure clearly distinguishes between buy and sell volumes for each market area, ensuring its suitability for further analysis.

# %% [markdown]
# ## **3.3 Flows**

# %% [markdown]
# ## **4. EXPLORATORY DATA ANALYSIS (EDA)**

# %% [markdown]
# ## **4.1 Prices**

# %% [markdown]
# **4.1.1 Initial validation of the dataset**

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17544 entries, 0 to 17543
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Delivery period (CET)  17544 non-null  object
#  1   EE                     17544 non-null  float64
#  2   LT                     17544 non-null  float64
#  3   LV                     17544 non-null  float64
#  4   AT                     17544 non-null  float64
#  5   BE                     17544 non-null  float64
#  6   FR                     17544 non-null  float64
#  7   GER                    17544 non-null  float64
#  8   NL                     17544 non-null  float64
#  9   DK1                    17544 non-null  float64
#  10  DK2                    17544 non-null  float64
#  11  FI                     17544 non-null  float64
#  12  NO1                    17544 non-null  float64
#  13  NO2                    17544 non-null  float64
#  14  NO3                    17544 non-null  float64
#  15  NO4                    17544 non-null  float64
#  16  NO5                    17544 non-null  float64
#  17  SE1                    17544 non-null  float64
#  18  SE2                    17544 non-null  float64
#  19  SE3                    17544 non-null  float64
#  20  SE4                    17544 non-null  float64
#  21  source_file            17544 non-null  object
#  22  Delivery day           17544 non-null  datetime64[ns]
#  23  hour                   17544 non-null  int32
#  24  timestamp              17544 non-null  datetime64[ns]
#  25  NO                     17544 non-null  float64
#  26  SE                     17544 non-null  float64
#  27  DK                     17544 non-null  float64
#  28  month                  17544 non-null  period[M]
# dtypes: datetime64[ns](2), float64(23), int32(1), object(2), period[M](1)
# memory usage: 3.8+ MB

# %%
print(prices.shape)
# Out:
# (17544, 29)

# %%
print(prices.head())
# Out:
#   Delivery period (CET)     EE     LT     LV     AT     BE     FR    GER  \
# 0         00:00 - 01:00  28.78  28.78  28.78  41.88  41.88  41.88  41.88
# 1         01:00 - 02:00  28.45  28.45  28.45  38.60  38.60  38.60  38.60
# 2         02:00 - 03:00  27.90  27.90  27.90  36.55  36.55  36.55  36.55
# 3         03:00 - 04:00  27.52  27.52  27.52  32.32  32.32  32.32  32.32
# 4         04:00 - 05:00  27.54  27.54  27.54  30.85  30.85  30.85  30.85
#
#       NL    DK1  ...    SE3    SE4  \
# 0  41.88  33.42  ...  28.78  28.78
# 1  38.60  31.77  ...  28.45  28.45
# 2  36.55  31.57  ...  27.90  27.90
# 3  32.32  31.28  ...  27.52  27.52
# 4  30.85  30.85  ...  27.54  27.54
#
#                                          source_file  Delivery day  hour  \
# 0  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...    2020-01-01     0
# 1  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...    2020-01-01     1
# 2  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...    2020-01-01     2
# 3  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...    2020-01-01     3
# 4  auction_prices_Day-ahead_EE,LT,LV,AT,BE,FR,GER...    2020-01-01     4
#
#             timestamp      NO     SE     DK    month
# 0 2020-01-01 00:00:00  30.604  28.78  33.42  2020-01
# 1 2020-01-01 01:00:00  30.442  28.45  31.77  2020-01
# 2 2020-01-01 02:00:00  30.102  27.90  31.57  2020-01
# 3 2020-01-01 03:00:00  29.776  27.52  31.28  2020-01
# 4 2020-01-01 04:00:00  29.448  27.54  30.85  2020-01
#
# [5 rows x 29 columns]

# %%
print(prices.isnull().sum())
# Out:
# Delivery period (CET)    0
# EE                       0
# LT                       0
# LV                       0
# AT                       0
# BE                       0
# FR                       0
# GER                      0
# NL                       0
# DK1                      0
# DK2                      0
# FI                       0
# NO1                      0
# NO2                      0
# NO3                      0
# NO4                      0
# NO5                      0
# SE1                      0
# SE2                      0
# SE3                      0
# SE4                      0
# source_file              0
# Delivery day             0
# hour                     0
# timestamp                0
# NO                       0
# SE                       0
# DK                       0
# month                    0
# dtype: int64

# %% [markdown]
# The processed prices dataset contains 17,544 rows and 25 columns, indicating that the data was successfully loaded and consolidated after preprocessing. The initial inspection shows that all variables contain the same number of non-null observations, which confirms the absence of missing values in the final dataset.
#
# The temporal structure is also correctly defined, including variables such as Delivery day, hour, and timestamp, which will facilitate the subsequent time-based analysis of electricity prices.
#
# In addition, the columns corresponding to market prices contain valid numerical values, although they are currently stored as object rather than numeric data types. Therefore, these variables may require conversion before performing statistical calculations in the following stages of the exploratory analysis.

# %% [markdown]
# Conversion of price to numeric data (float):

# %%
price_cols = ['EE', 'LT', 'LV', 'AT', 'BE', 'FR', 'GER', 'NL', 'DK1', 'DK2',
              'FI', 'NO1', 'NO2', 'NO3', 'NO4', 'NO5', 'SE1', 'SE2', 'SE3', 'SE4']

prices[price_cols] = prices[price_cols].astype(float)

# %% [markdown]
# **4.1.2 Descriptive analysis**

# %% [markdown]
# <u>4.1.2.1 Descriptive statistics by market area</u>

# %% [markdown]
# First of all we will analyze based on each bidding zone.

# %%
descriptive_stats = prices[price_cols].describe().T
print(descriptive_stats)
# Out:
#        count       mean        std     min      25%     50%      75%      max
# EE   17544.0  60.171799  57.015366   -1.73  26.9300  46.700  75.1625  1000.07
# LT   17544.0  62.207674  58.984931   -1.73  27.9800  47.590  77.1025  1000.07
# LV   17544.0  61.375862  57.749738   -1.73  27.3375  46.870  76.9025  1000.07
# AT   17544.0  69.947278  67.021554  -77.68  31.9200  47.645  79.7625   620.00
# BE   17544.0  67.951558  67.772925 -115.31  29.3075  45.975  78.4275   620.00
# FR   17544.0  70.634598  71.836834  -75.82  30.0975  46.900  79.1575   620.00
# GER  17544.0  63.614913  62.972404  -83.94  28.8800  45.160  76.3150   620.00
# NL   17544.0  67.553277  64.457033  -79.19  30.0975  45.600  79.1950   620.00
# DK1  17544.0  56.517318  56.961436  -58.80  21.5000  41.455  74.4400   620.00
# DK2  17544.0  58.119936  58.073287  -42.66  22.4275  42.900  73.6900   626.06
# FI   17544.0  50.151072  53.745514   -1.73  19.7000  38.490  62.7800  1000.07
# NO1  17544.0  41.942567  47.357799   -1.97   6.8600  27.360  58.4100   600.16
# NO2  17544.0  42.148325  47.220706   -1.97   6.8475  27.315  59.3500   600.16
# NO3  17544.0  25.241549  25.339290   -0.01   7.2600  17.950  38.5000   360.00
# NO4  17544.0  21.935985  23.417047   -0.01   7.1300  16.810  27.5500   360.00
# NO5  17544.0  41.835105  47.214182   -0.09   6.7700  27.180  58.3000   600.16
# SE1  17544.0  28.419612  26.094299   -1.97  11.2000  21.910  41.4750   360.00
# SE2  17544.0  28.450628  26.144352   -1.97  11.2000  21.900  41.4750   360.00
# SE3  17544.0  43.563238  49.502950   -1.97  14.3700  29.735  54.8025   626.06
# SE4  17544.0  53.152672  54.668950   -1.97  19.0100  40.050  67.3225   626.06

# %% [markdown]
# Basic descriptive statistics were computed for each market area included in the dataset in order to obtain an initial overview of electricity price behaviour. In all cases, each zone contains 17,544 observations, which indicates a homogeneous temporal coverage across all the analysed areas.
#
# The results reveal significant differences in average price levels between market zones. Central European markets such as France, Austria, Belgium, the Netherlands, and Germany show the highest mean values, whereas several Nordic areas, particularly NO3, NO4, SE1, and SE2, display considerably lower average prices.
#
# Likewise, price dispersion is not uniform across markets. Some zones, such as Belgium, France, Austria, and Germany, present higher standard deviations, reflecting greater variability in price behaviour throughout the analysed period. By contrast, other areas, mainly certain Nordic zones, show a more stable pattern.
#
# Finally, the statistics reveal the presence of negative minimum prices in several market areas, as well as particularly high maximum values in some markets. This suggests the existence of extreme market episodes, which will be examined in greater detail in the following sections.

# %% [markdown]
# <u>4.1.2.2 Analysis by country</u>

# %% [markdown]
# In the following step, we will analyze the price behaviour in countries with multiple bidding zones:

# %%
prices["NO"] = prices[["NO1", "NO2", "NO3", "NO4", "NO5"]].mean(axis=1)
prices["SE"] = prices[["SE1", "SE2", "SE3", "SE4"]].mean(axis=1)
prices["DK"] = prices[["DK1", "DK2"]].mean(axis=1)

# %%
country_cols = ["DK", "NO", "SE"]

# %%
country_stats = prices[country_cols].describe().T
print(country_stats)
# Out:
#       count       mean        std     min        25%     50%        75%  \
# DK  17544.0  57.318627  56.995218 -48.935  22.450000  42.195  73.035000
# NO  17544.0  34.620706  35.596080   0.000   6.789000  25.850  49.881000
# SE  17544.0  38.396537  35.455782  -1.970  14.988125  29.205  51.634375
#
#         max
# DK  620.000
# NO  383.052
# SE  388.050

# %% [markdown]
# Comparison between bidding zones and average price by country.

# %% [markdown]
# - Norway

# %%
norway_comparison = []

for zone in ["NO1", "NO2", "NO3", "NO4", "NO5"]:
    zone_mean = prices[zone].mean()
    country_mean = prices["NO"].mean()
    diff_mean = (prices[zone] - prices["NO"]).mean()
    
    norway_comparison.append({
        "Zone": zone,
        "Zone mean": round(zone_mean, 2),
        "Norway mean": round(country_mean, 2),
        "Mean difference vs Norway": round(diff_mean, 2)
    })

norway_comparison_df = pd.DataFrame(norway_comparison)
print(norway_comparison_df)
# Out:
#   Zone  Zone mean  Norway mean  Mean difference vs Norway
# 0  NO1      41.94        34.62                       7.32
# 1  NO2      42.15        34.62                       7.53
# 2  NO3      25.24        34.62                      -9.38
# 3  NO4      21.94        34.62                     -12.68
# 4  NO5      41.84        34.62                       7.21

# %% [markdown]
# As can be observed, three bidding zones (NO1, NO2 and NO5) present a similar average price, approximately 20% above the national mean. In contrast, NO3 and NO4 show significantly lower average prices, standing around 30% and 35% below the country’s average, respectively.
#
# This pattern suggests that the Norwegian electricity market is not homogeneous across bidding zones. A possible explanation is that the zones with higher average prices are located in the southern part of the country, where electricity demand is generally higher due to greater population concentration and economic activity. By contrast, NO3 and NO4 are situated in the northern part of Norway, where lower demand and a stronger presence of renewable generation, particularly hydropower and wind power, may contribute to lower price levels.

# %% [markdown]
# - Sweden

# %%
sweden_comparison = []

for zone in ["SE1", "SE2", "SE3", "SE4"]:
    zone_mean = prices[zone].mean()
    country_mean = prices["SE"].mean()
    diff_mean = (prices[zone] - prices["SE"]).mean()
    
    sweden_comparison.append({
        "Zone": zone,
        "Zone mean": round(zone_mean, 2),
        "Sweden mean": round(country_mean, 2),
        "Mean difference vs Sweden": round(diff_mean, 2)
    })

sweden_comparison_df = pd.DataFrame(sweden_comparison)
print(sweden_comparison_df)
# Out:
#   Zone  Zone mean  Sweden mean  Mean difference vs Sweden
# 0  SE1      28.42         38.4                      -9.98
# 1  SE2      28.45         38.4                      -9.95
# 2  SE3      43.56         38.4                       5.17
# 3  SE4      53.15         38.4                      14.76

# %% [markdown]
# A pattern similar to that observed in Norway can also be identified in Sweden. The northern bidding zones, SE1 and SE2, show average prices clearly below the national mean, whereas SE3 and especially SE4 remain above the country’s average. In particular, SE4 stands out as the most expensive Swedish market area, while SE1 and SE2 record the lowest average prices.
#
# This result suggests that the Swedish electricity market is also characterised by significant internal heterogeneity across bidding zones. A possible explanation is that the northern zones, which are less densely populated and have strong access to electricity generation resources, tend to exhibit lower prices, while the southern zones are associated with higher demand and therefore higher average price levels.

# %% [markdown]
# - Denmark

# %%
denmark_comparison = []

for zone in ["DK1", "DK2"]:
    zone_mean = prices[zone].mean()
    country_mean = prices["DK"].mean()
    diff_mean = (prices[zone] - prices["DK"]).mean()
    
    denmark_comparison.append({
        "Zone": zone,
        "Zone mean": round(zone_mean, 2),
        "Denmark mean": round(country_mean, 2),
        "Mean difference vs Denmark": round(diff_mean, 2)
    })

denmark_comparison_df = pd.DataFrame(denmark_comparison)
print(denmark_comparison_df)
# Out:
#   Zone  Zone mean  Denmark mean  Mean difference vs Denmark
# 0  DK1      56.52         57.32                        -0.8
# 1  DK2      58.12         57.32                         0.8

# %% [markdown]
# In contrast to Norway and Sweden, Denmark shows a much more homogeneous pattern across its bidding zones. DK1 remains only slightly below the national average, while DK2 is only marginally above it, with mean differences of approximately -0.8 and +0.8 respectively.
#
# These results indicate that price differences between Danish bidding zones are relatively limited, suggesting a more integrated internal market structure. Therefore, in the case of Denmark, the aggregated country price appears to be a good representation of the overall behaviour of the national market.

# %% [markdown]
# **4.1.3 Temporal Behaviour of Electricity Prices**

# %% [markdown]
# <u>4.1.3.1 Hourly behaviour of electricity prices</u>

# %%
hourly_avg = prices.groupby("hour")[price_cols].mean()

# %%
hourly_min = hourly_avg.idxmin()
hourly_max = hourly_avg.idxmax()

# %%
print("Hourly average prices:")
print(hourly_avg)

print("\nCheapest hour by market area:")
print(hourly_min)

print("\nMost expensive hour by market area:")
print(hourly_max)
# Out:
# Hourly average prices:
#              EE         LT         LV         AT         BE         FR  \
# hour
# 0     40.033201  42.137551  41.267264  59.347469  62.168304  64.526936
# 1     36.046156  38.118536  37.289138  55.426799  56.812285  59.576211
# 2     33.540369  35.597237  34.831860  53.348495  53.631819  56.839644
# 3     32.953228  35.099220  34.333557  50.932695  49.964897  51.588030
# 4     34.939850  36.801368  36.281395  51.454241  49.157059  49.820629
# 5     43.707360  44.476607  44.361765  56.450274  53.300096  54.919412
# 6     60.727893  61.322134  61.173406  68.396949  64.440123  65.866908
# 7     72.989836  74.076689  73.457387  78.603338  75.549795  77.556785
# 8     79.883666  81.229056  80.510930  82.804364  80.854856  83.159672
# 9     77.606211  79.565185  78.721259  79.691546  79.003201  81.948523
# 10    73.863639  75.722544  75.143844  75.579398  73.370862  77.328358
# 11    71.162052  73.950068  73.090068  74.219918  69.280780  74.609166
# 12    69.970889  72.643228  71.933092  72.238358  65.667332  73.556594
# 13    67.216306  69.582476  69.050670  68.321122  61.737907  68.257811
# 14    66.410752  68.056813  67.653830  66.606129  60.139029  65.002517
# 15    66.966744  68.766703  68.287839  68.268413  61.433803  64.690328
# 16    70.738673  72.355828  71.941149  71.504706  65.428523  67.456293
# 17    76.064692  78.426238  77.888454  79.654460  77.501669  76.916115
# 18    79.448276  81.450137  80.301012  85.692695  85.537332  85.606744
# 19    75.809986  79.201683  77.015130  88.796019  89.177839  90.400233
# 20    63.920410  67.857305  65.438851  82.970670  83.165636  84.254268
# 21    59.005841  61.088263  59.830944  74.866443  75.026005  77.074200
# 22    50.869480  52.946238  51.931833  70.793721  72.416170  74.451683
# 23    40.247661  42.513064  41.286005  62.766457  66.072066  69.823297
#
#             GER         NL        DK1        DK2         FI        NO1  \
# hour
# 0     53.753817  60.536197  46.540971  43.732654  29.141108  38.264460
# 1     50.105062  55.703160  43.598345  40.754090  27.034378  37.056799
# 2     47.998865  52.704761  41.997004  39.173762  25.810014  36.185089
# 3     46.305923  50.136306  40.831081  38.329713  25.759590  35.559576
# 4     47.009508  49.778960  41.342722  39.277962  27.574473  36.028454
# 5     50.974966  53.347360  44.666430  43.017456  36.448194  37.452189
# 6     62.332750  64.779220  55.401149  55.535404  50.648290  39.905992
# 7     73.853680  75.868276  66.335130  69.043051  62.342613  44.004610
# 8     78.109699  81.548591  71.136183  76.031724  68.183338  47.915568
# 9     73.767921  79.033529  67.470356  71.760205  66.027373  47.448276
# 10    68.320328  72.615034  62.302148  66.566648  63.925171  45.731724
# 11    65.575855  68.369330  59.684979  63.622613  62.208386  44.184049
# 12    61.805499  64.500821  56.048482  60.473639  60.336772  43.137114
# 13    57.581614  61.117893  52.551614  57.345253  58.123037  42.297182
# 14    56.448865  60.256758  51.552394  55.981190  57.319330  42.006279
# 15    59.333215  62.294651  53.161176  57.993215  57.948591  42.713269
# 16    64.299713  67.273133  57.138892  62.985363  61.516033  44.484979
# 17    75.259508  79.978550  67.413187  72.709343  66.440492  46.851710
# 18    81.670807  84.586799  71.903078  75.852394  68.476799  46.788235
# 19    84.013776  87.166867  72.904569  75.144596  62.525828  45.100876
# 20    77.428824  81.586457  66.712914  67.413502  48.103776  42.944364
# 21    69.110369  74.133653  60.569343  60.350274  46.027798  41.874295
# 22    65.245923  70.739330  56.187921  54.970014  40.426689  40.328140
# 23    56.451436  63.223023  48.965554  46.814391  31.277661  38.358386
#
#             NO2        NO3        NO4        NO5        SE1        SE2  \
# hour
# 0     38.892353  22.124213  19.561628  38.280219  24.365335  24.366224
# 1     37.769343  21.402066  18.781067  37.120985  23.347456  23.349412
# 2     36.933461  20.883324  18.342011  36.269850  22.698714  22.700629
# 3     36.339932  20.805910  18.268550  35.667415  22.568550  22.569439
# 4     36.828659  21.312503  18.698222  36.147620  23.277702  23.277811
# 5     38.198933  22.545089  19.778495  37.565855  25.212955  25.209877
# 6     40.389453  23.959179  21.006689  39.931204  27.431204  27.423871
# 7     43.633379  26.287373  22.620520  43.572558  30.313215  30.341956
# 8     46.937907  28.606389  24.553488  47.097825  33.010602  33.063762
# 9     46.824460  28.536115  24.428659  46.858044  32.764856  32.818126
# 10    45.292572  28.093064  24.143187  45.366252  32.054432  32.095486
# 11    44.266772  27.353160  23.535855  43.942927  31.173502  31.219275
# 12    43.257237  26.971696  23.254487  42.930219  30.719111  30.743174
# 13    42.431300  26.743338  23.102189  42.154049  30.208618  30.237852
# 14    42.113023  26.500848  23.018988  42.019398  29.623789  29.677852
# 15    42.822161  26.790958  23.338057  42.701874  29.903844  29.959808
# 16    44.473830  27.148153  23.588085  44.508878  30.326484  30.380834
# 17    46.539029  27.616170  23.853023  46.810766  31.334692  31.392763
# 18    46.891751  27.304391  23.514241  46.682449  31.267510  31.330725
# 19    45.410246  26.930657  23.324268  44.996279  31.126033  31.192763
# 20    43.300752  25.862079  22.641929  42.892722  29.210315  29.276457
# 21    42.286279  25.187401  22.010506  41.853912  28.292093  28.342462
# 22    40.798591  24.257592  21.237004  40.315458  27.088509  27.096635
# 23    38.928386  22.575499  19.862490  38.355773  24.751163  24.747866
#
#             SE3        SE4
# hour
# 0     27.240438  35.710561
# 1     25.528235  33.068126
# 2     24.598741  31.299836
# 3     24.473324  30.987141
# 4     25.688153  32.498167
# 5     29.829850  37.115390
# 6     38.788824  50.793953
# 7     51.446854  64.966867
# 8     59.878276  71.710506
# 9     57.686484  68.305431
# 10    55.127319  64.078358
# 11    53.094049  61.515513
# 12    50.813447  58.663023
# 13    48.545363  55.555814
# 14    47.694405  54.174008
# 15    49.197319  55.622599
# 16    52.916320  60.063242
# 17    58.431135  68.001395
# 18    58.745951  70.723748
# 19    54.086498  69.457168
# 20    45.577852  61.160274
# 21    41.159713  54.564254
# 22    35.829644  47.247456
# 23    29.139508  38.381300
#
# Cheapest hour by market area:
# EE     3
# LT     3
# LV     3
# AT     3
# BE     4
# FR     4
# GER    3
# NL     4
# DK1    3
# DK2    3
# FI     3
# NO1    3
# NO2    3
# NO3    3
# NO4    3
# NO5    3
# SE1    3
# SE2    3
# SE3    3
# SE4    3
# dtype: int32
#
# Most expensive hour by market area:
# EE      8
# LT     18
# LV      8
# AT     19
# BE     19
# FR     19
# GER    19
# NL     19
# DK1    19
# DK2     8
# FI     18
# NO1     8
# NO2     8
# NO3     8
# NO4     8
# NO5     8
# SE1     8
# SE2     8
# SE3     8
# SE4     8
# dtype: int32

# %%
hourly_avg.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='hour'>

# %%
import os
import matplotlib.pyplot as plt

groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway" : ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden" : ["SE1", "SE2", "SE3", "SE4"],
    "Denmark" : ["DK1", "DK2"]
}

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Prices\hourly_prices"
os.makedirs(base_path, exist_ok=True)

hourly_avg = prices.groupby("hour")[price_cols].mean()

for group_name, zones in groups.items():
    plt.figure(figsize=(12, 6))
    
    for zone in zones:
        plt.plot(hourly_avg.index, hourly_avg[zone], label=zone)
    
    plt.title(f'Hourly Average Electricity Prices - {group_name} Markets')
    plt.xlabel('Hour of the day')
    plt.ylabel('Average price (EUR/MWh)')
    plt.xticks(range(24))
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)  
    plt.tight_layout()
    
    plt.savefig(os.path.join(base_path, f"{group_name}_hourly_prices.png"), dpi=300)
    plt.close()

# %% [markdown]
# The hourly plots reveal that electricity prices follow a clear intraday structure across all market groups, although the degree of similarity between zones differs considerably. In general, prices tend to be lower during the early morning hours, increase sharply after the beginning of daily activity, and reach their highest values either in the morning or in the evening depending on the market group.
#
# In the Baltic group, the three market areas display very similar hourly profiles, which suggests a relatively homogeneous intraday behaviour. Differences between zones are mainly observed in the price level rather than in the overall shape of the daily curve.
#
# In the CWE group, the market areas also follow a common pattern, although with higher average price levels and a more pronounced evening peak. This indicates a stronger concentration of high prices during the late hours of the day.
#
# By contrast, the Nordic group shows the greatest internal heterogeneity. Although all zones share a broadly similar daily structure, relevant differences can be observed both in average price levels and in the magnitude of hourly fluctuations. This confirms that the Nordic market cannot be treated as fully uniform, especially when comparing Norwegian and Swedish bidding zones with the rest of the group.

# %% [markdown]
# <u>4.1.3.2 Daily evolution of electricity prices</u>

# %%
daily_avg = prices.groupby("Delivery day")[price_cols].mean()
print(daily_avg.head())
# Out:
#                      EE         LT         LV         AT         BE  \
# Delivery day
# 2020-01-01    27.736667  27.736667  27.736667  35.033333  35.448750
# 2020-01-02    26.765000  26.765000  26.765000  40.136250  38.995000
# 2020-01-03    24.011667  24.011667  24.011667  38.112500  37.766667
# 2020-01-04    23.962500  23.962500  23.962500  33.272083  35.648333
# 2020-01-05    33.056667  33.056667  33.056667  35.696667  36.259167
#
#                      FR        GER         NL        DK1        DK2  \
# Delivery day
# 2020-01-01    35.206250  34.964167  34.578333  30.988750  30.988750
# 2020-01-02    39.460833  38.869167  38.780000  30.578750  38.348333
# 2020-01-03    36.835000  26.111250  37.245417  23.237917  25.877917
# 2020-01-04    34.336667  20.322917  33.757917  19.671250  19.855000
# 2020-01-05    36.045417  35.552500  35.177500  30.745417  32.676250
#
#                      FI        NO1        NO2        NO3        NO4  \
# Delivery day
# 2020-01-01    27.736667  30.936250  30.936250  27.736667  27.736667
# 2020-01-02    26.765000  30.822500  30.822500  26.765000  26.765000
# 2020-01-03    22.636250  29.207500  29.207500  22.682500  22.682500
# 2020-01-04    21.167083  28.879583  28.879583  24.279167  24.241667
# 2020-01-05    29.650833  30.697083  30.697083  29.650833  28.695000
#
#                     NO5        SE1        SE2        SE3        SE4
# Delivery day
# 2020-01-01    30.936250  27.736667  27.736667  27.736667  27.736667
# 2020-01-02    30.822500  26.765000  26.765000  26.765000  26.765000
# 2020-01-03    29.207500  22.636250  22.636250  22.636250  22.636250
# 2020-01-04    28.879583  21.167083  21.167083  21.167083  21.167083
# 2020-01-05    30.697083  29.650833  29.650833  29.650833  29.650833

# %%
groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway" : ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden" : ["SE1", "SE2", "SE3", "SE4"],
    "Denmark" : ["DK1", "DK2"]
}

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Prices\daily_prices"
os.makedirs(base_path, exist_ok=True)

daily_avg = prices.groupby("Delivery day")[price_cols].mean()

for group_name, zones in groups.items():
    plt.figure(figsize=(12, 6))
    
    for zone in zones:
        plt.plot(daily_avg.index, daily_avg[zone], label=zone, linewidth=1)
    
    plt.title(f'Daily Average Electricity Prices - {group_name} Markets')
    plt.xlabel('Day')
    plt.ylabel('Average price (EUR/MWh)')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout()
    
    plt.savefig(os.path.join(base_path, f"{group_name}_daily_prices.png"), dpi=300)
    plt.close()

# %% [markdown]
# Conclusions...

# %% [markdown]
# <u>4.1.3.3 Monthly behaviour and seasonal patterns</u>

# %%
prices["month"] = prices["Delivery day"].dt.to_period("M")

# %%
monthly_avg = prices.groupby("month")[price_cols].mean()
print(monthly_avg.head())
# Out:
#                 EE         LT         LV         AT         BE         FR  \
# month
# 2020-01  30.821344  30.821344  30.821344  40.702406  37.884624  38.006384
# 2020-02  28.105733  27.769986  28.054813  29.109023  28.354770  26.246006
# 2020-03  24.022113  23.997510  24.022113  24.603594  24.017995  23.832073
# 2020-04  23.694333  23.310167  23.516944  18.307069  14.723833  13.450042
# 2020-05  25.021142  24.518320  24.527433  17.523280  15.394462  14.862177
#
#                GER         NL        DK1        DK2         FI        NO1  \
# month
# 2020-01  35.034906  37.102621  24.994543  27.385242  27.163212  24.628562
# 2020-02  21.919009  29.557845  17.585072  18.816997  24.434267  12.456868
# 2020-03  22.485828  24.740000  18.264455  20.010511  20.377995   8.048977
# 2020-04  17.093125  19.009722  14.533778  17.354861  19.820542   4.693097
# 2020-05  17.596505  17.648427  16.053992  19.044073  19.464973   7.190403
#
#                NO2        NO3        NO4        NO5        SE1        SE2  \
# month
# 2020-01  24.628562  23.501156  23.464664  24.627594  23.264140  23.264140
# 2020-02  12.334756  13.744626  13.710963  12.456868  14.390187  14.390187
# 2020-03   8.013755   9.017201   9.017201   8.048829   9.006985   9.006985
# 2020-04   4.691736   4.651306   4.740944   4.693097   5.126028   5.126028
# 2020-05   7.165040   8.690054   8.842003   7.190403   9.500780   9.500780
#
#                SE3        SE4
# month
# 2020-01  23.734624  26.386707
# 2020-02  18.389397  18.561221
# 2020-03  13.843863  15.969206
# 2020-04   8.998181  13.743819
# 2020-05  12.737930  14.028468

# %%
groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway" : ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden" : ["SE1", "SE2", "SE3", "SE4"],
    "Denmark" : ["DK1", "DK2"]
}

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Prices\monthly_prices"
os.makedirs(base_path, exist_ok=True)

prices["month"] = prices["Delivery day"].dt.to_period("M")
monthly_avg = prices.groupby("month")[price_cols].mean()
monthly_avg.index = monthly_avg.index.astype(str)

for group_name, zones in groups.items():
    plt.figure(figsize=(12, 6))
    
    for zone in zones:
        plt.plot(monthly_avg.index, monthly_avg[zone], marker='o', label=zone)
    
    plt.title(f'Monthly Average Electricity Prices - {group_name} Markets')
    plt.xlabel('Month')
    plt.ylabel('Average price (EUR/MWh)')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    plt.savefig(os.path.join(base_path, f"{group_name}_monthly_prices.png"), dpi=300)
    plt.close()

# %%
import os
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# =========================
# GROUPS
# =========================
groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway": ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden": ["SE1", "SE2", "SE3", "SE4"],
    "Denmark": ["DK1", "DK2"]
}

# =========================
# PATHS
# =========================
db_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\data\thesis_database.db"
base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Prices\monthly_prices_from_db"
os.makedirs(base_path, exist_ok=True)

# =========================
# CONNECT TO SQLITE
# =========================
conn = sqlite3.connect(db_path)

# =========================
# READ DATA FROM DB
# =========================
query = """
SELECT
    p.delivery_day,
    p.hour,
    p.price_value,
    bz.zone_code
FROM Prices p
JOIN BiddingZones bz
    ON p.zone_id = bz.zone_id
"""

prices_db = pd.read_sql_query(query, conn)
conn.close()

# =========================
# PREPROCESS
# =========================
prices_db["delivery_day"] = pd.to_datetime(prices_db["delivery_day"])
prices_db["hour"] = prices_db["hour"].astype(int)
prices_db["price_value"] = pd.to_numeric(prices_db["price_value"], errors="coerce")

print(prices_db.head())
print(prices_db.shape)

# =========================
# OPTIONAL CHECK:
# pivot to similar structure as original EDA
# rows = timestamps/hours, columns = zones
# =========================
prices_pivot = prices_db.pivot_table(
    index=["delivery_day", "hour"],
    columns="zone_code",
    values="price_value",
    aggfunc="mean"   # por si en DST hay dos registros con misma hour
).reset_index()

prices_pivot.columns.name = None

print(prices_pivot.head())

# =========================
# MONTH COLUMN
# =========================
prices_pivot["month"] = prices_pivot["delivery_day"].dt.to_period("M")

# detectar columnas de zonas
non_zone_cols = ["delivery_day", "hour", "month"]
price_cols = [col for col in prices_pivot.columns if col not in non_zone_cols]

# media mensual por zona
monthly_avg = prices_pivot.groupby("month")[price_cols].mean()
monthly_avg.index = monthly_avg.index.astype(str)

print(monthly_avg.head())

# =========================
# PLOTS
# =========================
for group_name, zones in groups.items():
    plt.figure(figsize=(12, 6))

    available_zones = [z for z in zones if z in monthly_avg.columns]

    for zone in available_zones:
        plt.plot(monthly_avg.index, monthly_avg[zone], marker='o', label=zone)

    plt.title(f'Monthly Average Electricity Prices - {group_name} Markets')
    plt.xlabel('Month')
    plt.ylabel('Average price (EUR/MWh)')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.xticks(rotation=45)
    plt.tight_layout()

    plt.savefig(os.path.join(base_path, f"{group_name}_monthly_prices.png"), dpi=300)
    plt.show()
    plt.close()
# Out:
#   delivery_day  hour  price_value zone_code
# 0   2020-01-01     0        28.78        EE
# 1   2020-01-01     0        28.78        LT
# 2   2020-01-01     0        28.78        LV
# 3   2020-01-01     0        41.88        AT
# 4   2020-01-01     0        41.88        BE
# (350880, 4)
#   delivery_day  hour     AT     BE    DK1    DK2     EE     FI     FR    GER  \
# 0   2020-01-01     0  41.88  41.88  33.42  33.42  28.78  28.78  41.88  41.88
# 1   2020-01-01     1  38.60  38.60  31.77  31.77  28.45  28.45  38.60  38.60
# 2   2020-01-01     2  36.55  36.55  31.57  31.57  27.90  27.90  36.55  36.55
# 3   2020-01-01     3  32.32  32.32  31.28  31.28  27.52  27.52  32.32  32.32
# 4   2020-01-01     4  30.85  30.85  30.85  30.85  27.54  27.54  30.85  30.85
#
#    ...     NL    NO1    NO2    NO3    NO4    NO5    SE1    SE2    SE3    SE4
# 0  ...  41.88  31.82  31.82  28.78  28.78  31.82  28.78  28.78  28.78  28.78
# 1  ...  38.60  31.77  31.77  28.45  28.45  31.77  28.45  28.45  28.45  28.45
# 2  ...  36.55  31.57  31.57  27.90  27.90  31.57  27.90  27.90  27.90  27.90
# 3  ...  32.32  31.28  31.28  27.52  27.52  31.28  27.52  27.52  27.52  27.52
# 4  ...  30.85  30.72  30.72  27.54  27.54  30.72  27.54  27.54  27.54  27.54
#
# [5 rows x 22 columns]
#                 AT         BE        DK1        DK2         EE         FI  \
# month
# 2020-01  40.702406  37.884624  24.994543  27.385242  30.821344  27.163212
# 2020-02  29.109023  28.354770  17.585072  18.816997  28.105733  24.434267
# 2020-03  24.603594  24.017995  18.264455  20.010511  24.022113  20.377995
# 2020-04  18.307069  14.723833  14.533778  17.354861  23.694333  19.820542
# 2020-05  17.523280  15.394462  16.053992  19.044073  25.021142  19.464973
#
#                 FR        GER         LT         LV         NL        NO1  \
# month
# 2020-01  38.006384  35.034906  30.821344  30.821344  37.102621  24.628562
# 2020-02  26.246006  21.919009  27.769986  28.054813  29.557845  12.456868
# 2020-03  23.832073  22.485828  23.997510  24.022113  24.740000   8.048977
# 2020-04  13.450042  17.093125  23.310167  23.516944  19.009722   4.693097
# 2020-05  14.862177  17.596505  24.518320  24.527433  17.648427   7.190403
#
#                NO2        NO3        NO4        NO5        SE1        SE2  \
# month
# 2020-01  24.628562  23.501156  23.464664  24.627594  23.264140  23.264140
# 2020-02  12.334756  13.744626  13.710963  12.456868  14.390187  14.390187
# 2020-03   8.013755   9.017201   9.017201   8.048829   9.006985   9.006985
# 2020-04   4.691736   4.651306   4.740944   4.693097   5.126028   5.126028
# 2020-05   7.165040   8.690054   8.842003   7.190403   9.500780   9.500780
#
#                SE3        SE4
# month
# 2020-01  23.734624  26.386707
# 2020-02  18.389397  18.561221
# 2020-03  13.843863  15.969206
# 2020-04   8.998181  13.743819
# 2020-05  12.737930  14.028468

# %% [markdown]
# Conclusions

# %% [markdown]
# **4.1.4 Detection and treatment of missing values**

# %%
print(prices.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# As part of the exploratory data analysis, the dataset was also checked for missing values. This verification confirmed that the processed prices dataset contains no missing observations across any of the analysed variables. Consequently, no imputation or additional handling of missing data was necessary.

# %% [markdown]
# **4.1.5 Identification of outliers**

# %% [markdown]
# <u>Bidding zone outliers</u>

# %%
outlier_summary = []

for zone in price_cols:
    q1 = prices[zone].quantile(0.25)
    q3 = prices[zone].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    outliers = prices[(prices[zone] < lower_bound) | (prices[zone] > upper_bound)]
    
    outlier_summary.append({
        "Zone": zone,
        "Q1": round(q1, 2),
        "Q3": round(q3, 2),
        "IQR": round(iqr, 2),
        "Lower bound": round(lower_bound, 2),
        "Upper bound": round(upper_bound, 2),
        "Number of outliers": len(outliers),
        "Percentage of outliers": round(len(outliers) / len(prices) * 100, 2)
    })

outlier_summary_df = pd.DataFrame(outlier_summary)
print(outlier_summary_df.sort_values("Number of outliers", ascending=False))
# Out:
#    Zone     Q1     Q3    IQR  Lower bound  Upper bound  Number of outliers  \
# 5    FR  30.10  79.16  49.06       -43.49       152.75                2023
# 4    BE  29.31  78.43  49.12       -44.37       152.11                1948
# 3    AT  31.92  79.76  47.84       -39.84       151.53                1940
# 7    NL  30.10  79.19  49.10       -43.55       152.84                1810
# 6   GER  28.88  76.32  47.44       -42.27       147.47                1595
# 9   DK2  22.43  73.69  51.26       -54.47       150.58                1144
# 0    EE  26.93  75.16  48.23       -45.42       147.51                1087
# 1    LT  27.98  77.10  49.12       -45.70       150.79                1087
# 2    LV  27.34  76.90  49.57       -47.01       151.25                1060
# 19  SE4  19.01  67.32  48.31       -53.46       139.79                1056
# 8   DK1  21.50  74.44  52.94       -57.91       153.85                1038
# 18  SE3  14.37  54.80  40.43       -46.28       115.45                1022
# 10   FI  19.70  62.78  43.08       -44.92       127.40                 847
# 14  NO4   7.13  27.55  20.42       -23.50        58.18                 723
# 15  NO5   6.77  58.30  51.53       -70.53       135.60                 652
# 11  NO1   6.86  58.41  51.55       -70.46       135.73                 651
# 12  NO2   6.85  59.35  52.50       -71.91       138.10                 591
# 17  SE2  11.20  41.48  30.28       -34.21        86.89                 437
# 16  SE1  11.20  41.48  30.28       -34.21        86.89                 428
# 13  NO3   7.26  38.50  31.24       -39.60        85.36                 322
#
#     Percentage of outliers
# 5                    11.53
# 4                    11.10
# 3                    11.06
# 7                    10.32
# 6                     9.09
# 9                     6.52
# 0                     6.20
# 1                     6.20
# 2                     6.04
# 19                    6.02
# 8                     5.92
# 18                    5.83
# 10                    4.83
# 14                    4.12
# 15                    3.72
# 11                    3.71
# 12                    3.37
# 17                    2.49
# 16                    2.44
# 13                    1.84

# %% [markdown]
# <u> Maximum and minimum price outliers</u>

# %%
extreme_values = pd.DataFrame({
    "Min price": prices[price_cols].min(),
    "Max price": prices[price_cols].max()
}).sort_values("Max price", ascending=False)

print(extreme_values)
# Out:
#      Min price  Max price
# EE       -1.73    1000.07
# LT       -1.73    1000.07
# FI       -1.73    1000.07
# LV       -1.73    1000.07
# SE4      -1.97     626.06
# DK2     -42.66     626.06
# SE3      -1.97     626.06
# BE     -115.31     620.00
# AT      -77.68     620.00
# DK1     -58.80     620.00
# NL      -79.19     620.00
# GER     -83.94     620.00
# FR      -75.82     620.00
# NO2      -1.97     600.16
# NO5      -0.09     600.16
# NO1      -1.97     600.16
# NO3      -0.01     360.00
# NO4      -0.01     360.00
# SE1      -1.97     360.00
# SE2      -1.97     360.00

# %%
groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway": ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden": ["SE1", "SE2", "SE3", "SE4"],
    "Denmark": ["DK1", "DK2"]
}

for group_name, zones in groups.items():
    plt.figure(figsize=(10, 5))
    prices[zones].boxplot(showfliers=True)
    
    plt.title(f'Boxplot of Electricity Prices - {group_name}')
    plt.ylabel('Price (EUR/MWh)')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    
    plt.show()

# %% [markdown]
# The outlier analysis highlights the presence of frequent and significant extreme price events across all market areas. These extreme values, particularly positive price spikes, are not isolated anomalies but rather intrinsic characteristics of electricity markets.
#
# While Baltic and CWE markets show relatively homogeneous behaviour across their respective zones, the Nordic market presents a much higher degree of internal heterogeneity. In particular, clear structural differences are observed within Norway and Sweden, where northern and southern zones exhibit markedly different price distributions.
#
# Additionally, the presence of negative prices in several markets confirms the occurrence of specific supply-demand imbalances. Overall, these findings reinforce the importance of considering both spatial and temporal variability when analysing electricity price dynamics.

# %% [markdown]
# **4.1.6 Correlation analysis**

# %% [markdown]
# <u> Correlation matrix</u>

# %%
correlation_matrix = prices[price_cols].corr()
print(correlation_matrix)
# Out:
#            EE        LT        LV        AT        BE        FR       GER  \
# EE   1.000000  0.981523  0.988417  0.814115  0.780664  0.784755  0.821464
# LT   0.981523  1.000000  0.992963  0.837472  0.804971  0.808340  0.848228
# LV   0.988417  0.992963  1.000000  0.829012  0.796723  0.800945  0.837258
# AT   0.814115  0.837472  0.829012  1.000000  0.968943  0.977230  0.959542
# BE   0.780664  0.804971  0.796723  0.968943  1.000000  0.977284  0.951007
# FR   0.784755  0.808340  0.800945  0.977230  0.977284  1.000000  0.930900
# GER  0.821464  0.848228  0.837258  0.959542  0.951007  0.930900  1.000000
# NL   0.788684  0.812600  0.803605  0.963519  0.979977  0.962538  0.950162
# DK1  0.828273  0.856621  0.845284  0.899209  0.891223  0.869070  0.943754
# DK2  0.869910  0.893762  0.883751  0.864513  0.846129  0.827409  0.911219
# FI   0.935620  0.919335  0.927207  0.734552  0.699276  0.709963  0.746552
# NO1  0.790656  0.801691  0.799636  0.875285  0.859921  0.865787  0.857350
# NO2  0.789049  0.801301  0.798933  0.880645  0.865347  0.870647  0.863458
# NO3  0.594964  0.580341  0.588269  0.497126  0.472897  0.483446  0.494814
# NO4  0.593500  0.577407  0.584572  0.510840  0.485630  0.503374  0.495257
# NO5  0.789112  0.800200  0.798215  0.874938  0.859318  0.865497  0.856284
# SE1  0.602563  0.583836  0.593727  0.479094  0.457449  0.468847  0.482622
# SE2  0.602214  0.583976  0.593891  0.479180  0.457189  0.468447  0.482926
# SE3  0.883190  0.882765  0.882896  0.789851  0.765134  0.765088  0.814274
# SE4  0.901690  0.923800  0.912397  0.835036  0.813460  0.801026  0.874260
#
#            NL       DK1       DK2        FI       NO1       NO2       NO3  \
# EE   0.788684  0.828273  0.869910  0.935620  0.790656  0.789049  0.594964
# LT   0.812600  0.856621  0.893762  0.919335  0.801691  0.801301  0.580341
# LV   0.803605  0.845284  0.883751  0.927207  0.799636  0.798933  0.588269
# AT   0.963519  0.899209  0.864513  0.734552  0.875285  0.880645  0.497126
# BE   0.979977  0.891223  0.846129  0.699276  0.859921  0.865347  0.472897
# FR   0.962538  0.869070  0.827409  0.709963  0.865787  0.870647  0.483446
# GER  0.950162  0.943754  0.911219  0.746552  0.857350  0.863458  0.494814
# NL   1.000000  0.903453  0.857759  0.705198  0.873410  0.879279  0.484185
# DK1  0.903453  1.000000  0.963849  0.768502  0.868734  0.875615  0.560868
# DK2  0.857759  0.963849  1.000000  0.822336  0.834725  0.835621  0.574297
# FI   0.705198  0.768502  0.822336  1.000000  0.748973  0.743569  0.617627
# NO1  0.873410  0.868734  0.834725  0.748973  1.000000  0.995287  0.672010
# NO2  0.879279  0.875615  0.835621  0.743569  0.995287  1.000000  0.669102
# NO3  0.484185  0.560868  0.574297  0.617627  0.672010  0.669102  1.000000
# NO4  0.491656  0.547423  0.564682  0.614005  0.678859  0.671010  0.941242
# NO5  0.872801  0.867113  0.832954  0.747010  0.998392  0.994096  0.673463
# SE1  0.465225  0.554544  0.574026  0.639725  0.623462  0.619813  0.941638
# SE2  0.465015  0.555005  0.574392  0.639567  0.622736  0.619092  0.942794
# SE3  0.773165  0.855456  0.894439  0.921399  0.828584  0.821111  0.643156
# SE4  0.825050  0.924481  0.961060  0.863251  0.827068  0.826661  0.609318
#
#           NO4       NO5       SE1       SE2       SE3       SE4
# EE   0.593500  0.789112  0.602563  0.602214  0.883190  0.901690
# LT   0.577407  0.800200  0.583836  0.583976  0.882765  0.923800
# LV   0.584572  0.798215  0.593727  0.593891  0.882896  0.912397
# AT   0.510840  0.874938  0.479094  0.479180  0.789851  0.835036
# BE   0.485630  0.859318  0.457449  0.457189  0.765134  0.813460
# FR   0.503374  0.865497  0.468847  0.468447  0.765088  0.801026
# GER  0.495257  0.856284  0.482622  0.482926  0.814274  0.874260
# NL   0.491656  0.872801  0.465225  0.465015  0.773165  0.825050
# DK1  0.547423  0.867113  0.554544  0.555005  0.855456  0.924481
# DK2  0.564682  0.832954  0.574026  0.574392  0.894439  0.961060
# FI   0.614005  0.747010  0.639725  0.639567  0.921399  0.863251
# NO1  0.678859  0.998392  0.623462  0.622736  0.828584  0.827068
# NO2  0.671010  0.994096  0.619813  0.619092  0.821111  0.826661
# NO3  0.941242  0.673463  0.941638  0.942794  0.643156  0.609318
# NO4  1.000000  0.680107  0.885398  0.883632  0.647341  0.603292
# NO5  0.680107  1.000000  0.624221  0.623498  0.825710  0.824994
# SE1  0.885398  0.624221  1.000000  0.999157  0.659182  0.611223
# SE2  0.883632  0.623498  0.999157  1.000000  0.659201  0.611552
# SE3  0.647341  0.825710  0.659182  0.659201  1.000000  0.932186
# SE4  0.603292  0.824994  0.611223  0.611552  0.932186  1.000000

# %% [markdown]
# <u> Heatmap of correlations</u>

# %%
groups = {
    "Baltic": ["EE", "LT", "LV"],
    "CWE": ["AT", "BE", "FR", "GER", "NL"],
    "Nordic": ["DK1", "DK2", "FI", "NO1", "NO2", "NO3", "NO4", "NO5", "SE1", "SE2", "SE3", "SE4"],
    "Norway": ["NO1", "NO2", "NO3", "NO4", "NO5"],
    "Sweden": ["SE1", "SE2", "SE3", "SE4"],
    "Denmark": ["DK1", "DK2"]
}

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix of Electricity Prices by Market Area")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

for group_name, zones in groups.items():
    corr = prices[zones].corr()
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title(f"Correlation Matrix - {group_name}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# The correlation analysis reveals a high degree of synchronization within most market groups, particularly in the Baltic and CWE regions, where electricity prices exhibit strong positive correlations across all areas. This indicates a high level of market integration and similar responses to underlying market conditions.
#
# In contrast, the Nordic market displays a more complex structure, with clear subgroups of highly correlated zones. In particular, southern zones such as NO1, NO2, NO5, SE3, SE4, and the Danish bidding areas show strong correlations both internally and with Central European markets. On the other hand, northern zones such as NO3, NO4, SE1, and SE2 form a distinct cluster with lower price levels and weaker correlations with southern regions.
#
# This pattern is especially evident in Norway, where two well-defined submarkets can be identified: a southern cluster with very high internal correlation, and a northern cluster that behaves more independently.
#
# Overall, these results confirm that while some electricity markets behave in a highly integrated manner, others exhibit significant spatial heterogeneity, which must be taken into account in further analysis and modelling.

# %% [markdown]
# ## **4.2 Volumes**

# %%
buy_cols = [col for col in volumes.columns if col.endswith("_Buy")]
sell_cols = [col for col in volumes.columns if col.endswith("_Sell")]

# %% [markdown]
# **4.2.1 Initial validation of the processed dataset**

# %%
print(volumes.shape)
print(volumes.head())
print(volumes.isnull().sum().sum())
print(len(buy_cols), len(sell_cols))
print(volumes["Delivery day"].min())
print(volumes["Delivery day"].max())
# Out:
# (17544, 46)
#   Delivery period (CET)  EE_Buy  EE_Sell  LT_Buy  LT_Sell  LV_Buy  LV_Sell  \
# 0         00:00 - 01:00   688.8    283.8  1005.3   1703.4   689.7    220.3
# 1         01:00 - 02:00   680.7    284.8   965.3   1677.5   663.4    215.4
# 2         02:00 - 03:00   669.8    281.2   936.2   1365.5   637.2    217.9
# 3         03:00 - 04:00   666.4    266.2   931.5   1309.5   619.1    218.0
# 4         04:00 - 05:00   663.0    252.6   927.6   1001.5   618.4    316.0
#
#    AT_Buy  AT_Sell  BE_Buy  ...  SE2_Sell  SE3_Buy  SE3_Sell  SE4_Buy  \
# 0   452.0     22.6   119.5  ...    3762.5   7477.8   10059.4   2151.5
# 1   536.2    143.8   122.8  ...    3386.6   7278.4   10132.4   2066.3
# 2   576.6     84.2   129.8  ...    3334.4   7100.4   10192.6   1986.5
# 3   626.6     35.6   137.9  ...    3328.0   6960.6   10259.1   1899.2
# 4   596.6      0.0   150.6  ...    3437.6   6925.3   10371.9   1850.8
#
#    SE4_Sell  Delivery day  hour           timestamp  \
# 0     684.6    2020-01-01     0 2020-01-01 00:00:00
# 1     727.0    2020-01-01     1 2020-01-01 01:00:00
# 2     777.5    2020-01-01     2 2020-01-01 02:00:00
# 3     823.9    2020-01-01     3 2020-01-01 03:00:00
# 4     863.1    2020-01-01     4 2020-01-01 04:00:00
#
#                                          source_file    month
# 0  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...  2020-01
# 1  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...  2020-01
# 2  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...  2020-01
# 3  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...  2020-01
# 4  auction_volumes_EE,LT,LV,AT,BE,FR,GER,NL,DK1,D...  2020-01
#
# [5 rows x 46 columns]
# 0
# 20 20
# 2020-01-01 00:00:00
# 2021-12-31 00:00:00

# %% [markdown]
# Before starting the exploratory analysis of trading volumes, an initial validation of the processed dataset was carried out. This step confirmed that the dataset contains 17,544 hourly observations covering the period from January 1st, 2020 to December 31st, 2021, with no missing values. The final structure includes 20 buy series and 20 sell series, together with the corresponding temporal variables, which makes the dataset suitable for subsequent descriptive and temporal analysis.

# %% [markdown]
# **4.2.2 Descriptive analysis of trading volumes**

# %%
buy_stats = volumes[buy_cols].describe().T
sell_stats = volumes[sell_cols].describe().T

print("Buy statistics:")
print(buy_stats)

print("\nSell statistics:")
print(sell_stats)
# Out:
# Buy statistics:
#            count         mean          std     min       25%      50%  \
# EE_Buy   17544.0   851.551573   198.454799   401.8   704.975   825.30
# LT_Buy   17544.0  1438.025815   231.841240   794.1  1270.600  1434.10
# LV_Buy   17544.0   834.808704   164.280524   469.1   697.175   836.40
# AT_Buy   17544.0   321.233464   199.400763     0.0   160.900   281.30
# BE_Buy   17544.0   240.917145   126.913032     0.0   147.200   224.90
# FR_Buy   17544.0   521.712751   380.902068     0.0   269.000   453.60
# GER_Buy  17544.0  1794.388606  1353.669386     0.0   682.175  1555.40
# NL_Buy   17544.0   928.807718   453.492192     0.0   591.700   868.90
# DK1_Buy  17544.0  1643.689056   472.900702   804.8  1273.575  1560.85
# DK2_Buy  17544.0  1047.095674   489.275404   348.9   571.000  1043.35
# FI_Buy   17544.0  6454.502502  1258.923137  3476.2  5528.900  6290.15
# NO1_Buy  17544.0  3930.392242  1488.891548  1514.8  2746.475  3613.75
# NO2_Buy  17544.0  3596.472543   588.891931  2324.3  3120.175  3553.10
# NO3_Buy  17544.0  2883.776089   438.246392  1928.6  2523.200  2823.90
# NO4_Buy  17544.0  1581.599447   297.145650   948.5  1323.000  1596.30
# NO5_Buy  17544.0  1557.951163   374.321783   830.7  1276.800  1503.70
# SE1_Buy  17544.0  1241.688566   198.297686   874.7  1087.900  1214.15
# SE2_Buy  17544.0  1476.575331   324.097101   705.7  1229.700  1440.00
# SE3_Buy  17544.0  7992.111086  1737.283852  4370.7  6711.200  7779.50
# SE4_Buy  17544.0  2229.464244   563.913663   986.1  1812.575  2176.85
#
#               75%      max
# EE_Buy    974.500   1514.4
# LT_Buy   1594.800   2311.1
# LV_Buy    963.700   1263.1
# AT_Buy    484.900   1093.3
# BE_Buy    320.600    807.7
# FR_Buy    723.000   2911.6
# GER_Buy  2618.250   8306.4
# NL_Buy   1218.425   3150.0
# DK1_Buy  1982.700   3079.1
# DK2_Buy  1468.950   2381.1
# FI_Buy   7311.150  10249.8
# NO1_Buy  4982.300   8717.2
# NO2_Buy  4010.150   5451.3
# NO3_Buy  3219.250   4182.1
# NO4_Buy  1814.325   2386.1
# NO5_Buy  1798.225   2515.6
# SE1_Buy  1370.800   2025.6
# SE2_Buy  1703.625   2517.2
# SE3_Buy  9101.150  14026.6
# SE4_Buy  2599.700   4061.1
#
# Sell statistics:
#             count         mean          std     min       25%      50%  \
# EE_Sell   17544.0   490.003836   246.239608    50.9   303.500   464.80
# LT_Sell   17544.0   779.267738   346.725172    97.6   521.900   728.50
# LV_Sell   17544.0   803.670719   460.280420    85.6   427.600   735.30
# AT_Sell   17544.0    17.997788    24.678140     0.0     2.000     9.70
# BE_Sell   17544.0   118.493907    91.832010     0.0    45.500    94.40
# FR_Sell   17544.0   438.981749   252.084041     0.0   256.200   385.40
# GER_Sell  17544.0  2502.582387  1776.261663     0.0  1154.400  2222.20
# NL_Sell   17544.0  1184.981236   801.042593     0.0   475.100  1125.80
# DK1_Sell  17544.0  2036.056874  1003.511845   283.1  1213.775  1914.60
# DK2_Sell  17544.0   767.646438   395.442629    13.0   445.050   758.30
# FI_Sell   17544.0  5557.292088  1259.755797  2568.8  4541.775  5478.45
# NO1_Sell  17544.0  2388.993673   615.290506  1031.9  1989.400  2318.15
# NO2_Sell  17544.0  5689.413988  1691.029936  1036.9  4396.600  5630.70
# NO3_Sell  17544.0  2769.420109   517.086922  1054.2  2406.100  2829.45
# NO4_Sell  17544.0  2445.106452   678.402724   647.1  1954.200  2392.30
# NO5_Sell  17544.0  3552.542453  1158.534612   604.4  2765.050  3438.90
# SE1_Sell  17544.0  2974.296272   819.326248   579.4  2429.700  3056.30
# SE2_Sell  17544.0  5462.130512  1210.344650  1502.7  4518.375  5487.10
# SE3_Sell  17544.0  6884.861109  1650.078163  3229.1  5433.125  6788.60
# SE4_Sell  17544.0   500.725484   247.129973   123.0   307.700   458.10
#
#                75%      max
# EE_Sell    626.100   1426.1
# LT_Sell   1001.525   2405.0
# LV_Sell   1137.700   2589.3
# AT_Sell     24.300    314.0
# BE_Sell    184.700    539.9
# FR_Sell    586.525   1945.0
# GER_Sell  3497.500  10323.7
# NL_Sell   1837.825   3344.9
# DK1_Sell  2725.550   5546.3
# DK2_Sell  1045.425   1955.1
# FI_Sell   6516.775   9586.7
# NO1_Sell  2697.350   4128.0
# NO2_Sell  7005.325   9909.2
# NO3_Sell  3155.100   4134.2
# NO4_Sell  2920.950   3995.5
# NO5_Sell  4336.950   6532.1
# SE1_Sell  3528.300   5167.5
# SE2_Sell  6427.450   8439.0
# SE3_Sell  8211.700  10844.0
# SE4_Sell   629.400   1515.6

# %%
zones = [col.replace("_Buy", "") for col in buy_cols]

volume_summary = pd.DataFrame({
    "Zone": zones,
    "Mean Buy": [volumes[f"{z}_Buy"].mean() for z in zones],
    "Mean Sell": [volumes[f"{z}_Sell"].mean() for z in zones],
    "Std Buy": [volumes[f"{z}_Buy"].std() for z in zones],
    "Std Sell": [volumes[f"{z}_Sell"].std() for z in zones],
    "Min Buy": [volumes[f"{z}_Buy"].min() for z in zones],
    "Min Sell": [volumes[f"{z}_Sell"].min() for z in zones],
    "Max Buy": [volumes[f"{z}_Buy"].max() for z in zones],
    "Max Sell": [volumes[f"{z}_Sell"].max() for z in zones],
})

print(volume_summary.sort_values("Mean Buy", ascending=False))
# Out:
#    Zone     Mean Buy    Mean Sell      Std Buy     Std Sell  Min Buy  \
# 18  SE3  7992.111086  6884.861109  1737.283852  1650.078163   4370.7
# 10   FI  6454.502502  5557.292088  1258.923137  1259.755797   3476.2
# 11  NO1  3930.392242  2388.993673  1488.891548   615.290506   1514.8
# 12  NO2  3596.472543  5689.413988   588.891931  1691.029936   2324.3
# 13  NO3  2883.776089  2769.420109   438.246392   517.086922   1928.6
# 19  SE4  2229.464244   500.725484   563.913663   247.129973    986.1
# 6   GER  1794.388606  2502.582387  1353.669386  1776.261663      0.0
# 8   DK1  1643.689056  2036.056874   472.900702  1003.511845    804.8
# 14  NO4  1581.599447  2445.106452   297.145650   678.402724    948.5
# 15  NO5  1557.951163  3552.542453   374.321783  1158.534612    830.7
# 17  SE2  1476.575331  5462.130512   324.097101  1210.344650    705.7
# 1    LT  1438.025815   779.267738   231.841240   346.725172    794.1
# 16  SE1  1241.688566  2974.296272   198.297686   819.326248    874.7
# 9   DK2  1047.095674   767.646438   489.275404   395.442629    348.9
# 7    NL   928.807718  1184.981236   453.492192   801.042593      0.0
# 0    EE   851.551573   490.003836   198.454799   246.239608    401.8
# 2    LV   834.808704   803.670719   164.280524   460.280420    469.1
# 5    FR   521.712751   438.981749   380.902068   252.084041      0.0
# 3    AT   321.233464    17.997788   199.400763    24.678140      0.0
# 4    BE   240.917145   118.493907   126.913032    91.832010      0.0
#
#     Min Sell  Max Buy  Max Sell
# 18    3229.1  14026.6   10844.0
# 10    2568.8  10249.8    9586.7
# 11    1031.9   8717.2    4128.0
# 12    1036.9   5451.3    9909.2
# 13    1054.2   4182.1    4134.2
# 19     123.0   4061.1    1515.6
# 6        0.0   8306.4   10323.7
# 8      283.1   3079.1    5546.3
# 14     647.1   2386.1    3995.5
# 15     604.4   2515.6    6532.1
# 17    1502.7   2517.2    8439.0
# 1       97.6   2311.1    2405.0
# 16     579.4   2025.6    5167.5
# 9       13.0   2381.1    1955.1
# 7        0.0   3150.0    3344.9
# 0       50.9   1514.4    1426.1
# 2       85.6   1263.1    2589.3
# 5        0.0   2911.6    1945.0
# 3        0.0   1093.3     314.0
# 4        0.0    807.7     539.9

# %% [markdown]
# Descriptive statistics were computed for trading volumes in order to obtain an initial overview of market activity across all bidding zones. The results reveal substantial differences in average trading volumes between areas, indicating that market participation is not evenly distributed across the analysed regions.
#
# In terms of buy volumes, SE3 and FI stand out as the most active market areas, followed by several Norwegian zones such as NO1 and NO2. A similar pattern can be observed for sell volumes, where SE3, FI, NO2 and SE2 show particularly high average values. These results suggest that some bidding zones play a much more prominent role in the overall trading activity than others.
#
# The comparison between buy and sell volumes also reveals clear structural differences across market areas. In some zones, such as SE4, NO1, FI, LT and EE, average buy volumes are higher than average sell volumes, whereas in others, including NO2, SE1, SE2, NO5, GER and DK1, the opposite pattern is observed. This indicates that market areas do not behave symmetrically and may perform different roles within the broader electricity market.
#
# In addition, several zones display high standard deviations and large maximum values, especially SE3, FI, NO1 and NO2, which points to considerable variation in trading activity over time. Finally, the presence of zero minimum values in some markets suggests that one side of the market may occasionally register no trading activity during specific hours.

# %% [markdown]
# **4.2.3 Temporal behaviour of trading volumes**

# %% [markdown]
# <u> 4.2.3.1 Hourly behaviour of trading volumes</u>

# %%
hourly_buy = volumes.groupby("hour")[buy_cols].mean()
hourly_sell = volumes.groupby("hour")[sell_cols].mean()

# %%
buy_groups = {
    "Baltic": ["EE_Buy", "LT_Buy", "LV_Buy"],
    "CWE": ["AT_Buy", "BE_Buy", "FR_Buy", "GER_Buy", "NL_Buy"],
    "Nordic": ["DK1_Buy", "DK2_Buy", "FI_Buy", "NO1_Buy", "NO2_Buy", "NO3_Buy", "NO4_Buy", "NO5_Buy", "SE1_Buy", "SE2_Buy", "SE3_Buy", "SE4_Buy"],
    "Norway" : ["NO1_Buy", "NO2_Buy", "NO3_Buy", "NO4_Buy", "NO5_Buy"],
    "Sweden" : ["SE1_Buy", "SE2_Buy", "SE3_Buy", "SE4_Buy"],
    "Denmark" : ["DK1_Buy", "DK2_Buy"]
}

sell_groups = {
    "Baltic": ["EE_Sell", "LT_Sell", "LV_Sell"],
    "CWE": ["AT_Sell", "BE_Sell", "FR_Sell", "GER_Sell", "NL_Sell"],
    "Nordic": ["DK1_Sell", "DK2_Sell", "FI_Sell", "NO1_Sell", "NO2_Sell", "NO3_Sell", "NO4_Sell", "NO5_Sell", "SE1_Sell", "SE2_Sell", "SE3_Sell", "SE4_Sell"],
    "Norway" : ["NO1_Sell", "NO2_Sell", "NO3_Sell", "NO4_Sell", "NO5_Sell"],
    "Sweden" : ["SE1_Sell", "SE2_Sell", "SE3_Sell", "SE4_Sell"],
    "Denmark" : ["DK1_Sell", "DK2_Sell"]    
}

# %%
import os
import matplotlib.pyplot as plt

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\hourly_volumes"
os.makedirs(base_path, exist_ok=True)

# Buy
for group_name, cols in buy_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(hourly_buy.index, hourly_buy[col], label=col.replace("_Buy", ""))
    plt.title(f'Hourly Average Buy Volumes - {group_name} Markets')
    plt.xlabel('Hour of the day')
    plt.ylabel('Average volume')
    plt.xticks(range(24))
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_hourly_buy_volumes.png"), dpi=300)
    plt.close()

# Sell
for group_name, cols in sell_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(hourly_sell.index, hourly_sell[col], label=col.replace("_Sell", ""))
    plt.title(f'Hourly Average Sell Volumes - {group_name} Markets')
    plt.xlabel('Hour of the day')
    plt.ylabel('Average volume')
    plt.xticks(range(24))
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_hourly_sell_volumes.png"), dpi=300)
    plt.close()

# %% [markdown]
# <u> 4.2.3.2 Daily evolution of trading volumes</u>

# %%
daily_buy = volumes.groupby("Delivery day")[buy_cols].mean()
daily_sell = volumes.groupby("Delivery day")[sell_cols].mean()

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\daily_volumes"
os.makedirs(base_path, exist_ok=True)

# Buy
for group_name, cols in buy_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(daily_buy.index, daily_buy[col], label=col.replace("_Buy", ""), linewidth=1)
    plt.title(f'Daily Average Buy Volumes - {group_name} Markets')
    plt.xlabel('Day')
    plt.ylabel('Average volume')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_daily_buy_volumes.png"), dpi=300)
    plt.close()

# Sell
for group_name, cols in sell_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(daily_sell.index, daily_sell[col], label=col.replace("_Sell", ""), linewidth=1)
    plt.title(f'Daily Average Sell Volumes - {group_name} Markets')
    plt.xlabel('Day')
    plt.ylabel('Average volume')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_daily_sell_volumes.png"), dpi=300)
    plt.close()

# %% [markdown]
# <u> 4.3.3.3 Monthly behaviour and seasonal patterns</u>

# %%
volumes["month"] = volumes["Delivery day"].dt.to_period("M")

monthly_buy = volumes.groupby("month")[buy_cols].mean()
monthly_sell = volumes.groupby("month")[sell_cols].mean()

monthly_buy.index = monthly_buy.index.astype(str)
monthly_sell.index = monthly_sell.index.astype(str)

base_path = r"C:\Users\HUGO\Desktop\Q8 - NORUEGA\TFG\tfg\NordPoool\ExcelFilesNoProcessed\Volumes\monthly_volumes"
os.makedirs(base_path, exist_ok=True)

# Buy
for group_name, cols in buy_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(monthly_buy.index, monthly_buy[col], marker='o', label=col.replace("_Buy", ""))
    plt.title(f'Monthly Average Buy Volumes - {group_name} Markets')
    plt.xlabel('Month')
    plt.ylabel('Average volume')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_monthly_buy_volumes.png"), dpi=300)
    plt.close()

# Sell
for group_name, cols in sell_groups.items():
    plt.figure(figsize=(12, 6))
    for col in cols:
        plt.plot(monthly_sell.index, monthly_sell[col], marker='o', label=col.replace("_Sell", ""))
    plt.title(f'Monthly Average Sell Volumes - {group_name} Markets')
    plt.xlabel('Month')
    plt.ylabel('Average volume')
    plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(os.path.join(base_path, f"{group_name}_monthly_sell_volumes.png"), dpi=300)
    plt.close()

# %% [markdown]
# **4.2.4 Identification of outliers**

# %% [markdown]
# <u> Buy table outliers</u>

# %%
buy_outlier_summary = []

for col in buy_cols:
    q1 = volumes[col].quantile(0.25)
    q3 = volumes[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers = volumes[(volumes[col] < lower_bound) | (volumes[col] > upper_bound)]

    buy_outlier_summary.append({
        "Variable": col,
        "Q1": round(q1, 2),
        "Q3": round(q3, 2),
        "IQR": round(iqr, 2),
        "Lower bound": round(lower_bound, 2),
        "Upper bound": round(upper_bound, 2),
        "Number of outliers": len(outliers),
        "Percentage of outliers": round(len(outliers) / len(volumes) * 100, 2)
    })

buy_outlier_summary_df = pd.DataFrame(buy_outlier_summary)
print(buy_outlier_summary_df.sort_values("Number of outliers", ascending=False))
# Out:
#    Variable       Q1       Q3      IQR  Lower bound  Upper bound  \
# 5    FR_Buy   269.00   723.00   454.00      -412.00      1404.00
# 6   GER_Buy   682.18  2618.25  1936.07     -2221.94      5522.36
# 0    EE_Buy   704.98   974.50   269.52       300.69      1378.79
# 7    NL_Buy   591.70  1218.43   626.73      -348.39      2158.51
# 16  SE1_Buy  1087.90  1370.80   282.90       663.55      1795.15
# 4    BE_Buy   147.20   320.60   173.40      -112.90       580.70
# 18  SE3_Buy  6711.20  9101.15  2389.95      3126.28     12686.08
# 1    LT_Buy  1270.60  1594.80   324.20       784.30      2081.10
# 19  SE4_Buy  1812.57  2599.70   787.12       631.89      3780.39
# 11  NO1_Buy  2746.48  4982.30  2235.83      -607.26      8336.04
# 3    AT_Buy   160.90   484.90   324.00      -325.10       970.90
# 10   FI_Buy  5528.90  7311.15  1782.25      2855.52      9984.53
# 17  SE2_Buy  1229.70  1703.62   473.92       518.81      2414.51
# 12  NO2_Buy  3120.18  4010.15   889.98      1785.21      5345.11
# 8   DK1_Buy  1273.57  1982.70   709.13       209.89      3046.39
# 9   DK2_Buy   571.00  1468.95   897.95      -775.93      2815.88
# 13  NO3_Buy  2523.20  3219.25   696.05      1479.12      4263.33
# 14  NO4_Buy  1323.00  1814.32   491.33       586.01      2551.31
# 15  NO5_Buy  1276.80  1798.22   521.42       494.66      2580.36
# 2    LV_Buy   697.18   963.70   266.52       297.39      1363.49
#
#     Number of outliers  Percentage of outliers
# 5                  562                    3.20
# 6                  209                    1.19
# 0                  188                    1.07
# 7                  180                    1.03
# 16                 177                    1.01
# 4                  170                    0.97
# 18                 152                    0.87
# 1                   56                    0.32
# 19                  32                    0.18
# 11                  27                    0.15
# 3                   25                    0.14
# 10                  18                    0.10
# 17                  10                    0.06
# 12                   4                    0.02
# 8                    2                    0.01
# 9                    0                    0.00
# 13                   0                    0.00
# 14                   0                    0.00
# 15                   0                    0.00
# 2                    0                    0.00

# %% [markdown]
# <u> Sell table outliers</u>

# %%
buy_outlier_summary = []

for col in buy_cols:
    q1 = volumes[col].quantile(0.25)
    q3 = volumes[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    outliers = volumes[(volumes[col] < lower_bound) | (volumes[col] > upper_bound)]

    buy_outlier_summary.append({
        "Variable": col,
        "Q1": round(q1, 2),
        "Q3": round(q3, 2),
        "IQR": round(iqr, 2),
        "Lower bound": round(lower_bound, 2),
        "Upper bound": round(upper_bound, 2),
        "Number of outliers": len(outliers),
        "Percentage of outliers": round(len(outliers) / len(volumes) * 100, 2)
    })

buy_outlier_summary_df = pd.DataFrame(buy_outlier_summary)
print(buy_outlier_summary_df.sort_values("Number of outliers", ascending=False))
# Out:
#    Variable       Q1       Q3      IQR  Lower bound  Upper bound  \
# 5    FR_Buy   269.00   723.00   454.00      -412.00      1404.00
# 6   GER_Buy   682.18  2618.25  1936.07     -2221.94      5522.36
# 0    EE_Buy   704.98   974.50   269.52       300.69      1378.79
# 7    NL_Buy   591.70  1218.43   626.73      -348.39      2158.51
# 16  SE1_Buy  1087.90  1370.80   282.90       663.55      1795.15
# 4    BE_Buy   147.20   320.60   173.40      -112.90       580.70
# 18  SE3_Buy  6711.20  9101.15  2389.95      3126.28     12686.08
# 1    LT_Buy  1270.60  1594.80   324.20       784.30      2081.10
# 19  SE4_Buy  1812.57  2599.70   787.12       631.89      3780.39
# 11  NO1_Buy  2746.48  4982.30  2235.83      -607.26      8336.04
# 3    AT_Buy   160.90   484.90   324.00      -325.10       970.90
# 10   FI_Buy  5528.90  7311.15  1782.25      2855.52      9984.53
# 17  SE2_Buy  1229.70  1703.62   473.92       518.81      2414.51
# 12  NO2_Buy  3120.18  4010.15   889.98      1785.21      5345.11
# 8   DK1_Buy  1273.57  1982.70   709.13       209.89      3046.39
# 9   DK2_Buy   571.00  1468.95   897.95      -775.93      2815.88
# 13  NO3_Buy  2523.20  3219.25   696.05      1479.12      4263.33
# 14  NO4_Buy  1323.00  1814.32   491.33       586.01      2551.31
# 15  NO5_Buy  1276.80  1798.22   521.42       494.66      2580.36
# 2    LV_Buy   697.18   963.70   266.52       297.39      1363.49
#
#     Number of outliers  Percentage of outliers
# 5                  562                    3.20
# 6                  209                    1.19
# 0                  188                    1.07
# 7                  180                    1.03
# 16                 177                    1.01
# 4                  170                    0.97
# 18                 152                    0.87
# 1                   56                    0.32
# 19                  32                    0.18
# 11                  27                    0.15
# 3                   25                    0.14
# 10                  18                    0.10
# 17                  10                    0.06
# 12                   4                    0.02
# 8                    2                    0.01
# 9                    0                    0.00
# 13                   0                    0.00
# 14                   0                    0.00
# 15                   0                    0.00
# 2                    0                    0.00

# %% [markdown]
# <u> Box plots of buy and sell volumes</u>

# %%
# Boxplots Buy
for group_name, cols in buy_groups.items():
    plt.figure(figsize=(10, 5))
    volumes[cols].boxplot()
    plt.title(f'Boxplot of Buy Volumes - {group_name}')
    plt.ylabel('Volume')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Boxplots Sell
for group_name, cols in sell_groups.items():
    plt.figure(figsize=(10, 5))
    volumes[cols].boxplot()
    plt.title(f'Boxplot of Sell Volumes - {group_name}')
    plt.ylabel('Volume')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **4.2.5 Correlation analysis**

# %% [markdown]
# <u> Corrrelation matrix</u>

# %% [markdown]
# - Buy

# %%
buy_corr = volumes[buy_cols].corr()
print(buy_corr)
# Out:
#            EE_Buy    LT_Buy    LV_Buy    AT_Buy    BE_Buy    FR_Buy   GER_Buy  \
# EE_Buy   1.000000  0.573631  0.833824 -0.119295  0.527904  0.449597  0.015993
# LT_Buy   0.573631  1.000000  0.488544  0.053168  0.380607  0.308846  0.019393
# LV_Buy   0.833824  0.488544  1.000000 -0.135156  0.473005  0.425033  0.159942
# AT_Buy  -0.119295  0.053168 -0.135156  1.000000 -0.327510 -0.132648 -0.381751
# BE_Buy   0.527904  0.380607  0.473005 -0.327510  1.000000  0.433572  0.124642
# FR_Buy   0.449597  0.308846  0.425033 -0.132648  0.433572  1.000000  0.157626
# GER_Buy  0.015993  0.019393  0.159942 -0.381751  0.124642  0.157626  1.000000
# NL_Buy   0.189352  0.034338  0.173325  0.089281  0.033198 -0.014435 -0.055945
# DK1_Buy  0.420777  0.301888  0.468662  0.480262  0.127605  0.196809 -0.221885
# DK2_Buy  0.274599  0.183255  0.305050  0.549152  0.028424  0.119249 -0.282648
# FI_Buy   0.861761  0.487925  0.649309  0.098142  0.246762  0.256538 -0.156291
# NO1_Buy  0.851450  0.478590  0.577443  0.102882  0.323207  0.333612 -0.153313
# NO2_Buy  0.817908  0.468638  0.578391  0.017811  0.251903  0.307871 -0.101527
# NO3_Buy  0.618090  0.360909  0.466730  0.431251  0.105559  0.204907 -0.270698
# NO4_Buy  0.723121  0.432094  0.491258  0.103518  0.117213  0.176047 -0.171338
# NO5_Buy  0.484280  0.310443  0.363304  0.547352 -0.073470  0.056730 -0.346406
# SE1_Buy  0.838572  0.516032  0.591869  0.007880  0.342195  0.347736 -0.083395
# SE2_Buy  0.702053  0.463540  0.523592  0.304088  0.202905  0.253854 -0.244085
# SE3_Buy  0.889029  0.517932  0.696754  0.041322  0.356771  0.364058 -0.074262
# SE4_Buy  0.846933  0.497937  0.683621  0.055933  0.336302  0.353581 -0.036621
#
#            NL_Buy   DK1_Buy   DK2_Buy    FI_Buy   NO1_Buy   NO2_Buy   NO3_Buy  \
# EE_Buy   0.189352  0.420777  0.274599  0.861761  0.851450  0.817908  0.618090
# LT_Buy   0.034338  0.301888  0.183255  0.487925  0.478590  0.468638  0.360909
# LV_Buy   0.173325  0.468662  0.305050  0.649309  0.577443  0.578391  0.466730
# AT_Buy   0.089281  0.480262  0.549152  0.098142  0.102882  0.017811  0.431251
# BE_Buy   0.033198  0.127605  0.028424  0.246762  0.323207  0.251903  0.105559
# FR_Buy  -0.014435  0.196809  0.119249  0.256538  0.333612  0.307871  0.204907
# GER_Buy -0.055945 -0.221885 -0.282648 -0.156291 -0.153313 -0.101527 -0.270698
# NL_Buy   1.000000  0.073250  0.051479  0.181344  0.189326  0.160955  0.134523
# DK1_Buy  0.073250  1.000000  0.920078  0.481118  0.481945  0.404583  0.745116
# DK2_Buy  0.051479  0.920078  1.000000  0.370770  0.401776  0.304892  0.721913
# FI_Buy   0.181344  0.481118  0.370770  1.000000  0.910445  0.895504  0.777506
# NO1_Buy  0.189326  0.481945  0.401776  0.910445  1.000000  0.905962  0.803576
# NO2_Buy  0.160955  0.404583  0.304892  0.895504  0.905962  1.000000  0.735868
# NO3_Buy  0.134523  0.745116  0.721913  0.777506  0.803576  0.735868  1.000000
# NO4_Buy  0.142471  0.362341  0.257528  0.878960  0.823523  0.864370  0.719638
# NO5_Buy  0.160883  0.731958  0.713767  0.726026  0.685140  0.677946  0.869196
# SE1_Buy  0.153050  0.369125  0.261371  0.879499  0.885049  0.860260  0.678064
# SE2_Buy  0.131094  0.647174  0.584093  0.820521  0.810506  0.757568  0.835737
# SE3_Buy  0.155273  0.514936  0.393977  0.930542  0.920634  0.904716  0.781214
# SE4_Buy  0.119964  0.572815  0.452196  0.889963  0.879906  0.868483  0.782117
#
#           NO4_Buy   NO5_Buy   SE1_Buy   SE2_Buy   SE3_Buy   SE4_Buy
# EE_Buy   0.723121  0.484280  0.838572  0.702053  0.889029  0.846933
# LT_Buy   0.432094  0.310443  0.516032  0.463540  0.517932  0.497937
# LV_Buy   0.491258  0.363304  0.591869  0.523592  0.696754  0.683621
# AT_Buy   0.103518  0.547352  0.007880  0.304088  0.041322  0.055933
# BE_Buy   0.117213 -0.073470  0.342195  0.202905  0.356771  0.336302
# FR_Buy   0.176047  0.056730  0.347736  0.253854  0.364058  0.353581
# GER_Buy -0.171338 -0.346406 -0.083395 -0.244085 -0.074262 -0.036621
# NL_Buy   0.142471  0.160883  0.153050  0.131094  0.155273  0.119964
# DK1_Buy  0.362341  0.731958  0.369125  0.647174  0.514936  0.572815
# DK2_Buy  0.257528  0.713767  0.261371  0.584093  0.393977  0.452196
# FI_Buy   0.878960  0.726026  0.879499  0.820521  0.930542  0.889963
# NO1_Buy  0.823523  0.685140  0.885049  0.810506  0.920634  0.879906
# NO2_Buy  0.864370  0.677946  0.860260  0.757568  0.904716  0.868483
# NO3_Buy  0.719638  0.869196  0.678064  0.835737  0.781214  0.782117
# NO4_Buy  1.000000  0.704436  0.822269  0.732907  0.837561  0.788440
# NO5_Buy  0.704436  1.000000  0.554635  0.752679  0.679072  0.697384
# SE1_Buy  0.822269  0.554635  1.000000  0.796760  0.874097  0.809324
# SE2_Buy  0.732907  0.752679  0.796760  1.000000  0.821134  0.782143
# SE3_Buy  0.837561  0.679072  0.874097  0.821134  1.000000  0.947726
# SE4_Buy  0.788440  0.697384  0.809324  0.782143  0.947726  1.000000

# %% [markdown]
# - Sell

# %%
sell_corr = volumes[sell_cols].corr()
print(sell_corr)
# Out:
#            EE_Sell   LT_Sell   LV_Sell   AT_Sell   BE_Sell   FR_Sell  \
# EE_Sell   1.000000  0.143941  0.314860  0.041443 -0.030014  0.222329
# LT_Sell   0.143941  1.000000  0.083078  0.206275  0.141045 -0.036138
# LV_Sell   0.314860  0.083078  1.000000 -0.074896 -0.042553 -0.036556
# AT_Sell   0.041443  0.206275 -0.074896  1.000000  0.161998  0.115024
# BE_Sell  -0.030014  0.141045 -0.042553  0.161998  1.000000  0.164782
# FR_Sell   0.222329 -0.036138 -0.036556  0.115024  0.164782  1.000000
# GER_Sell  0.035577  0.160853  0.102978  0.106766  0.227175  0.147134
# NL_Sell   0.013319  0.452030  0.001973  0.143480  0.148323 -0.178004
# DK1_Sell  0.082565  0.173540  0.220659  0.068868  0.152140  0.212485
# DK2_Sell  0.341080  0.000475  0.369787  0.000190 -0.017332  0.290672
# FI_Sell   0.469986  0.096836  0.613605  0.056370  0.074842  0.291617
# NO1_Sell  0.300398  0.030084  0.550199  0.047493  0.182323  0.205660
# NO2_Sell  0.335322  0.170881  0.561880  0.032389  0.014640  0.104188
# NO3_Sell  0.150496  0.341387  0.043537  0.117280  0.173902 -0.000399
# NO4_Sell  0.475684  0.104566  0.475658  0.066861  0.114135  0.110742
# NO5_Sell  0.333519  0.362016  0.424962  0.074173  0.169113  0.023356
# SE1_Sell  0.408756  0.048034  0.463506 -0.098739 -0.085233 -0.059710
# SE2_Sell  0.029438  0.303853  0.401896  0.085877  0.230869  0.082474
# SE3_Sell  0.065569  0.122739  0.394601  0.091641  0.178212  0.206228
# SE4_Sell  0.019532  0.123310  0.152697  0.029033  0.114075  0.209178
#
#           GER_Sell   NL_Sell  DK1_Sell  DK2_Sell   FI_Sell  NO1_Sell  \
# EE_Sell   0.035577  0.013319  0.082565  0.341080  0.469986  0.300398
# LT_Sell   0.160853  0.452030  0.173540  0.000475  0.096836  0.030084
# LV_Sell   0.102978  0.001973  0.220659  0.369787  0.613605  0.550199
# AT_Sell   0.106766  0.143480  0.068868  0.000190  0.056370  0.047493
# BE_Sell   0.227175  0.148323  0.152140 -0.017332  0.074842  0.182323
# FR_Sell   0.147134 -0.178004  0.212485  0.290672  0.291617  0.205660
# GER_Sell  1.000000  0.174897  0.244703  0.118527  0.070998  0.227502
# NL_Sell   0.174897  1.000000 -0.054561 -0.259123 -0.110833  0.098397
# DK1_Sell  0.244703 -0.054561  1.000000  0.627665  0.479668  0.282584
# DK2_Sell  0.118527 -0.259123  0.627665  1.000000  0.654010  0.334048
# FI_Sell   0.070998 -0.110833  0.479668  0.654010  1.000000  0.604691
# NO1_Sell  0.227502  0.098397  0.282584  0.334048  0.604691  1.000000
# NO2_Sell  0.129969  0.155368  0.255248  0.293010  0.628346  0.572940
# NO3_Sell  0.102141  0.430947  0.132649  0.043788  0.126058  0.194496
# NO4_Sell  0.035401  0.011490  0.108291  0.300502  0.557526  0.459801
# NO5_Sell  0.190624  0.398713  0.124423  0.073074  0.442160  0.564170
# SE1_Sell  0.078691  0.061490 -0.008085  0.136484  0.391724  0.355486
# SE2_Sell  0.243486  0.302901  0.425320  0.289556  0.549301  0.513320
# SE3_Sell  0.094783 -0.017772  0.621510  0.574066  0.732830  0.528954
# SE4_Sell  0.164522 -0.110748  0.790158  0.681717  0.439002  0.200775
#
#           NO2_Sell  NO3_Sell  NO4_Sell  NO5_Sell  SE1_Sell  SE2_Sell  \
# EE_Sell   0.335322  0.150496  0.475684  0.333519  0.408756  0.029438
# LT_Sell   0.170881  0.341387  0.104566  0.362016  0.048034  0.303853
# LV_Sell   0.561880  0.043537  0.475658  0.424962  0.463506  0.401896
# AT_Sell   0.032389  0.117280  0.066861  0.074173 -0.098739  0.085877
# BE_Sell   0.014640  0.173902  0.114135  0.169113 -0.085233  0.230869
# FR_Sell   0.104188 -0.000399  0.110742  0.023356 -0.059710  0.082474
# GER_Sell  0.129969  0.102141  0.035401  0.190624  0.078691  0.243486
# NL_Sell   0.155368  0.430947  0.011490  0.398713  0.061490  0.302901
# DK1_Sell  0.255248  0.132649  0.108291  0.124423 -0.008085  0.425320
# DK2_Sell  0.293010  0.043788  0.300502  0.073074  0.136484  0.289556
# FI_Sell   0.628346  0.126058  0.557526  0.442160  0.391724  0.549301
# NO1_Sell  0.572940  0.194496  0.459801  0.564170  0.355486  0.513320
# NO2_Sell  1.000000  0.287846  0.550843  0.692684  0.533996  0.573845
# NO3_Sell  0.287846  1.000000  0.241982  0.494700  0.132674  0.367012
# NO4_Sell  0.550843  0.241982  1.000000  0.524943  0.436496  0.243890
# NO5_Sell  0.692684  0.494700  0.524943  1.000000  0.465368  0.528559
# SE1_Sell  0.533996  0.132674  0.436496  0.465368  1.000000  0.292294
# SE2_Sell  0.573845  0.367012  0.243890  0.528559  0.292294  1.000000
# SE3_Sell  0.473039  0.111380  0.326936  0.321894  0.093279  0.615099
# SE4_Sell  0.106030  0.039425  0.004324 -0.021914 -0.093380  0.347336
#
#           SE3_Sell  SE4_Sell
# EE_Sell   0.065569  0.019532
# LT_Sell   0.122739  0.123310
# LV_Sell   0.394601  0.152697
# AT_Sell   0.091641  0.029033
# BE_Sell   0.178212  0.114075
# FR_Sell   0.206228  0.209178
# GER_Sell  0.094783  0.164522
# NL_Sell  -0.017772 -0.110748
# DK1_Sell  0.621510  0.790158
# DK2_Sell  0.574066  0.681717
# FI_Sell   0.732830  0.439002
# NO1_Sell  0.528954  0.200775
# NO2_Sell  0.473039  0.106030
# NO3_Sell  0.111380  0.039425
# NO4_Sell  0.326936  0.004324
# NO5_Sell  0.321894 -0.021914
# SE1_Sell  0.093279 -0.093380
# SE2_Sell  0.615099  0.347336
# SE3_Sell  1.000000  0.640093
# SE4_Sell  0.640093  1.000000

# %% [markdown]
# <u> Heatmap of correlations</u>

# %% [markdown]
# - Buy

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(buy_corr, annot=False, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix of Buy Volumes by Market Area")
plt.tight_layout()
plt.show()

# %%
for group_name, cols in buy_groups.items():
    corr = volumes[cols].corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title(f"Correlation Matrix of Buy Volumes - {group_name}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - Sell

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(sell_corr, annot=False, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix of Sell Volumes by Market Area")
plt.tight_layout()
plt.show()

# %%
for group_name, cols in sell_groups.items():
    corr = volumes[cols].corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title(f"Correlation Matrix of Sell Volumes - {group_name}")
    plt.tight_layout()
    plt.show()
